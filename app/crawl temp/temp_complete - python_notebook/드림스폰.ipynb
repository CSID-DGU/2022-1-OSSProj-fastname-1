# %%
import pandas as pd
import numpy as np
import csv

import requests
from bs4 import BeautifulSoup
import re
import urllib.request
import time
from time import sleep

from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import ssl
import time
from datetime import datetime

# %%
import datetime
from dateutil.parser import parse
from urllib.request import urlopen
context=ssl._create_unverified_context()

# %%
import datetime
import time

# %%
#드림스폰 일반 공모전 D-DAY 크롤링

dday_bef = []
tag = []
page_num = 1
while(page_num <=5):        
    url = 'https://www.dreamspon.com/scholarship/list.html?page='+str(page_num)+'&ordby=1'
    req = urllib.request.urlopen(url)
    res = req.read()
    soup = BeautifulSoup(res,'html.parser')
    days = soup.select(" .td_day > .count")
    target = soup.select(".hashtag")
    for i in range(len(days)):
        dday_bef.append((days[i].text))
        tag_tmp = ((target[i].get_text()).replace("#", "").replace("\n", " "))
        tag_tmp = tag_tmp.strip()
        tag_tmp = tag_tmp.split(" ")
        tag.append(tag_tmp)
    page_num += 1

# %%
link_test = []
page_num = 1
while(page_num <=5):        
    url = 'https://www.dreamspon.com/scholarship/list.html?page='+str(page_num)+'&ordby=1'
    req = urllib.request.urlopen(url)
    res = req.read()
    soup = BeautifulSoup(res,'html.parser')
    contests = soup.find_all("p",class_="title")
    days = soup.select(" .td_day > .count")        
    for i in range(len(days)):
        link_test.append(str(contests[i]).strip('[<p class="title"><a href="').strip('</a>'))
    page_num += 1

# %%
#링크 추출
link_bef=[]
for t in range(len(link_test)):
    link_address, title_name = link_test[t].split('">')
    link_ver1 = "https://www.dreamspon.com/" + link_address
    link_bef.append(link_ver1)

# %%
# 행사 이름
titles_bef = []
for t in range(len(link_test)):
    link_address, title_name = link_test[t].split('">')
    titles_bef.append(title_name)

# %%
# {"id":2,"first_name":"Brion","last_name":"Bonelle","email":"bbonelle1@mashable.com"}
dream_spon = []

for i in range(len(titles_bef)):
    li_tmp = {"title": titles_bef[i], "d-day": dday_bef[i], "link": link_bef[i], "tag": tag[i]}
    dream_spon.append(li_tmp)

# %%
dream = pd.DataFrame(dream_spon)
dream
# Out:
#                   title  d-day  \
# 0        하남형 소상공인 특별지원금    D-0
# 1    옹진군 인재육성장학 (2022년)    D-0
# 2    양평군교육발전 장학 (2022년)    D-0
# 3    수원시 소상공인 경영환경 개선사업    D-0
# 4           거제시 성적우수 장학    D-0
# ..                  ...    ...
# 61            청년도전 지원사업  D-239
# 62  경기도 청소년 종합심리검사 지원사업  D-239
# 63            성남시 입영지원금  D-157
# 64            위기가정 지원사업  D-239
# 65      주거취약계층 임차자금지원사업  D-239
#
#                                                  link                tag
# 0   https://www.dreamspon.com/scholarship/view.htm...  [기타지원, 일반인, 지역기준]
# 1   https://www.dreamspon.com/scholarship/view.htm...   [장학금, 초등학생, 중학생]
# 2   https://www.dreamspon.com/scholarship/view.htm...    [장학금, 대학생, 전문대]
# 3   https://www.dreamspon.com/scholarship/view.htm...  [기타지원, 일반인, 지역기준]
# 4   https://www.dreamspon.com/scholarship/view.htm...    [장학금, 대학생, 전문대]
# ..                                                ...                ...
# 61  https://www.dreamspon.com/scholarship/view.htm...    [기타지원, 일반인, 청년]
# 62  https://www.dreamspon.com/scholarship/view.htm...  [기타지원, 초등학생, 중학생]
# 63  https://www.dreamspon.com/scholarship/view.htm...  [기타지원, 일반인, 지역기준]
# 64  https://www.dreamspon.com/scholarship/view.htm...  [기타지원, 일반인, 푸른나눔]
# 65  https://www.dreamspon.com/scholarship/view.htm...  [기타지원, 일반인, 특수계층]
#
# [66 rows x 4 columns]

# %%
import json

with open('dream_spon', 'w', encoding="utf-8") as make_file: 
    json.dump(dream_spon, make_file, ensure_ascii = False, indent="\t")
