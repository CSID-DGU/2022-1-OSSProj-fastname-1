# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup
import urllib.request
import ssl

# %%
from dateutil.parser import parse
from urllib.request import urlopen
context=ssl._create_unverified_context()

# %%
dday_bef = []
tag = []
page_num = 1
while(page_num <=5):        
    url = 'https://www.dreamspon.com/scholarship/list.html?page='+str(page_num)+'&ordby=1'
    req = urllib.request.urlopen(url)
    res = req.read()
    soup = BeautifulSoup(res,'html.parser')
    days = soup.select(" .td_day > .count")
    target = soup.select(".hashtag")
    for i in range(len(days)):
        dday_bef.append((days[i].text))
        tag_tmp = ((target[i].get_text()).replace("#", "").replace("\n", " "))
        tag_tmp = tag_tmp.strip()
        tag_tmp = tag_tmp.split(" ")
        tag.append(tag_tmp)
    page_num += 1

# %%
link_test = []
page_num = 1
while(page_num <=5):        
    url = 'https://www.dreamspon.com/scholarship/list.html?page='+str(page_num)+'&ordby=1'
    req = urllib.request.urlopen(url)
    res = req.read()
    soup = BeautifulSoup(res,'html.parser')
    contests = soup.find_all("p",class_="title")
    days = soup.select(" .td_day > .count")        
    for i in range(len(days)):
        link_test.append(str(contests[i]).strip('[<p class="title"><a href="').strip('</a>'))
    page_num += 1

# %%
#링크 추출
link_bef=[]
for t in range(len(link_test)):
    link_address, title_name = link_test[t].split('">')
    link_ver1 = "https://www.dreamspon.com/" + link_address
    link_bef.append(link_ver1)

# %%
# 행사 이름
titles_bef = []
for t in range(len(link_test)):
    link_address, title_name = link_test[t].split('">')
    titles_bef.append(title_name)

# %%
# {"id":2,"first_name":"Brion","last_name":"Bonelle","email":"bbonelle1@mashable.com"}
dream_spon = []

for i in range(len(titles_bef)):
    li_tmp = {"title": titles_bef[i], "d-day": dday_bef[i], "link": link_bef[i], "tag": tag[i]}
    dream_spon.append(li_tmp)

# %%
dream = pd.DataFrame(dream_spon)
dream
# Out:
#                     title  d-day  \
# 0     제주 4∙3 평화장학 (2022년)    D-0
# 1       경기도 예술인 자립지원 (2차)    D-0
# 2       뮤즈온 2022 뮤지션 육성지원    D-0
# 3     남양주 북한이탈주민 수급자 지원사업    D-1
# 4              2022년 수림장학    D-1
# ..                    ...    ...
# 70          세종시 긴급복지지원 장학  D-233
# 71  천안 위기가정 주거안정 긴급 지원 사업  D-233
# 72         청년 마음건강 바우처 지원  D-233
# 73      고흥군 귀향인 자녀 어울림 장학  D-233
# 74              청년도전 지원사업  D-233
#
#                                                  link                    tag
# 0   https://www.dreamspon.com/scholarship/view.htm...       [장학금, 고등학생, 대학생]
# 1   https://www.dreamspon.com/scholarship/view.htm...      [기타지원, 일반인, 지역기준]
# 2   https://www.dreamspon.com/scholarship/view.htm...       [기타지원, 일반인, 뮤지션]
# 3   https://www.dreamspon.com/scholarship/view.htm...   [남양주시, 북한이탈주민, 정착지원]
# 4   https://www.dreamspon.com/scholarship/view.htm...     [장학금, 대학생, 자연과학계열]
# ..                                                ...                    ...
# 70  https://www.dreamspon.com/scholarship/view.htm...        [장학금, 대학생, 세종시]
# 71  https://www.dreamspon.com/scholarship/view.htm...    [일반인, 천안시, 풀뿌리희망재단]
# 72  https://www.dreamspon.com/scholarship/view.htm...  [청년, 심리상담서비스, 대한민국정부]
# 73  https://www.dreamspon.com/scholarship/view.htm...       [중학생, 고등학생, 귀향인]
# 74  https://www.dreamspon.com/scholarship/view.htm...        [기타지원, 일반인, 청년]
#
# [75 rows x 4 columns]

# %%
import json

with open('dream_spon.json', 'w', encoding="utf-8") as make_file: 
    json.dump(dream_spon, make_file, ensure_ascii = False, indent="\t")
