# %%
import pandas as pd
import numpy as np
import csv

import requests
from bs4 import BeautifulSoup
import re
import urllib.request
import time
from time import sleep
from urllib.request import urlopen

from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import ssl
context=ssl._create_unverified_context()

import time
from datetime import datetime

# %%
import datetime
from dateutil.parser import parse

# %%
custom_header = {
    'referer' : 'https://thinkyou.co.kr/contest/',
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.41 Safari/537.36'}

#해당 접속 사이트가 아닌 원본데이터가 오는 url 추적. network에서 가지고 온다.
url = "http://finance.daum.net/api/search/ranks?limit=10"

req = requests.get(url, headers = custom_header)    #custom_header를 사용하지 않으면 접근 불가

if req.status_code == requests.codes.ok:    
    print("접속 성공")
    stock_data = json.loads(req.text)        #json에 반환된 데이터가 들어가 있다.
    for rank in stock_data['data']:         #stock_data는 'data' key값에 모든 정보가 들어가 있다.
        print(rank['rank'], rank['symbolCode'], rank['name'], rank['tradePrice'])

else:
    print("Error code")

# %%
url ='https://thinkyou.co.kr/contest/sector.asp'

browser = Chrome('./chromedriver')

delay=3
browser.implicitly_wait(delay)

browser.get(url)

browser.maximize_window()

body = browser.find_element_by_tag_name('body')

try :

    browser.find_elements_by_xpath('//*[@id="searchFrm"]/div/dl[1]/dd/p[6]/label/span')[0].click()
    browser.find_elements_by_xpath('//*[@id="searchFrm"]/div/dl[2]/dd/p[1]/label/span')[0].click()
except:
    pass

page = browser.page_source
soup = BeautifulSoup(page, 'html.parser')
# Out:
# C:\Users\sangh\AppData\Local\Temp\ipykernel_10364\2876290942.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = Chrome('./chromedriver')
# C:\Users\sangh\AppData\Local\Temp\ipykernel_10364\2876290942.py:12: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   body = browser.find_element_by_tag_name('body')
# C:\Users\sangh\AppData\Local\Temp\ipykernel_10364\2876290942.py:16: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   browser.find_elements_by_xpath('//*[@id="searchFrm"]/div/dl[1]/dd/p[6]/label/span')[0].click()
# C:\Users\sangh\AppData\Local\Temp\ipykernel_10364\2876290942.py:17: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   browser.find_elements_by_xpath('//*[@id="searchFrm"]/div/dl[2]/dd/p[1]/label/span')[0].click()
# <html lang="ko" class="sub"><head>
#
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta property="og:type" content="website">
#
# 	<!-- Global site tag (gtag.js) - Google Analytics -->
# 	<script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-163306206-1"></script>
# 	<script>
# 	  window.dataLayer = window.dataLayer || [];
# 	  function gtag(){dataLayer.push(arguments);}
# 	  gtag('js', new Date());
#
# 	  gtag('config', 'UA-163306206-1');
# 	</script>
# 	<!-- Global site tag (gtag.js) - Google Analytics -->
# 	<meta http-equiv="Expires" content="10">
#
# 	<title>공모전/대외활동 | 씽유! 공모전·서포터즈 등 대외활동은 여기서</title>
# 	<meta property="og:site_name" content="thinkyou">
# 	<meta property="og:title" content="공모전/대외활동 | 씽유! 공모전·서포터즈 등 대외활동은 여기서">
# 	<meta name="description" content="공모전/대외활동 - 공모전, 대외활동은 씽유에서! 디자인공모전, 사진공모전, 영상공모전, 콘텐츠공모전, 대학생공모전, 서포터즈 등 모든 대외활동">
# 	<meta property="og:url" content="https://thinkyou.co.kr/">
# 	<meta property="og:description" content="공모전/대외활동 - 공모전, 대외활동은 씽유에서! 디자인공모전, 사진공모전, 영상공모전, 콘텐츠공모전, 대학생공모전, 서포터즈 등 모든 대외활동">
# 	<meta property="og:image" content="https://thinkyou.co.kr/images/sns_link.png">
# 	<meta name="author" content="씽유! 공모전·서포터즈 등 대외활동은 여기서">
# 	<meta name="viewport" content="width=1220, user-scalable=no">
# 	<meta name="format-detection" content="telephone=no">
# 	<meta name="subject" content="씽유! 공모전·서포터즈 등 대외활동은 여기서">
# 	<meta name="keywords" content="공모전,공모전사이트,대학생공모전,공모전정보,공모전일정,사진공모전,콘텐츠공모전,디자인공모전,광고공모전,영상공모전,문학공모전,대외활동,서포터즈,대학생대외활동">
# 	<meta name="description" content="공모전/대외활동 - 공모전, 대외활동은 씽유에서! 디자인공모전, 사진공모전, 영상공모전, 콘텐츠공모전, 대학생공모전, 서포터즈 등 모든 대외활동">
# 	<meta name="twitter:title" content="공모전/대외활동 | 씽유! 공모전·서포터즈 등 대외활동은 여기서">
# 	<meta name="twitter:url" content="https://thinkyou.co.kr/">
# 	<meta name="twitter:image" content="https://thinkyou.co.kr/images/sns_link.png">
# 	<meta name="twitter:description" content="공모전/대외활동 - 공모전, 대외활동은 씽유에서! 디자인공모전, 사진공모전, 영상공모전, 콘텐츠공모전, 대학생공모전, 서포터즈 등 모든 대외활동">
#
# 	</head><body data-pgcode="0101" id="body_1"><span itemscope="" itemtype="https://schema.org/Organization">
# 	<link itemprop="url" href="https://thinkyou.co.kr">
# 	<a itemprop="sameAs" href="https://www.facebook.com/thinkyou.co.kr"></a>
# 	<a itemprop="sameAs" href="https://blog.naver.com/thinku1125"></a>
# 	<a itemprop="sameAs" href="https://www.youtube.com/channel/UCyOGdgteJDVr5-8yq1pSezg"></a>
# 	</span>
#
# 	<link rel="canonical" href="https://thinkyou.co.kr/contest/sector.asp">
# 	<link rel="alternate" href="https://thinkyou.co.kr/mobile/contest/sector.asp">
#
# 	<link rel="shortcut icon" href="/images/favicon.ico" type="image/x-icon">
#
# 	<link rel="stylesheet" type="text/css" href="/common/css/jquery.ui.lastest.css">
# 	<link rel="stylesheet" type="text/css" href="/common/css/styles.css">
# 	<link href="/css/editorContent.css" rel="stylesheet" type="text/css">
#
# 	<script type="text/javascript" src="/common/js/jquery.lastest.js"></script>
# 	<script type="text/javascript" src="/common/js/jquery.ui.lastest.min.js"></script>
# 	<script type="text/javascript" src="/common/js/jquery.plugin.package.js"></script>
# 	<script type="text/javascript" src="/common/js/publisher.js?ver=2"></script>
# 	<script type="text/javascript" src="/js/plug-in/jquery.simplemodal/jquery.simplemodal.js"></script>
# 	<script type="text/javascript" src="/_lib/functions.js"></script>
#
# 	<!--[if lt IE 10]>
# 		<script type="text/javascript" src="/common/js/placeholder.js"></script>
# 	<![endif]-->
#
# 	<script src="//developers.kakao.com/sdk/js/kakao.min.js"></script>
# 	<script type="text/javascript">
# 	<!--
# 	var currentRootUrl = "";
#
# 	$(window).load(function(){
# 		var bsNum01 = $(".mBanner.slider01 .slider").length;// 베너
# 		if(bsNum01 > 1){
# 			$(".mBanner.slider01").slick({
# 				autoplay: true,
# 				slidesToShow: 1,
# 				slidesToScroll: 1,
# 				arrows: false,
# 				dots: false
# 			});
# 		}
#
# 		$("body").attr("id","body_1");
# 		AutoSourcing.setTemplate("<div>- 씽유에서 공모전 확인! <a href='https://thinkyou.co.kr/' target='_blank' >www.thinkyou.co.kr</a></div>");
# 		AutoSourcing.setString(1, "", "", "https://thinkyou.co.kr/");
# 		AutoSourcing.init('body_%id%');
#
# 		$(document).on("click",".likeBBsBtn",function(){
# 			if ($(this).hasClass("notLogin")){
# 				login("")
# 			}else{
# 				var index = $(this).attr("dataidx")
# 				var obj = $(this)
#
# 				var params = "idx="+index;
# 				$.ajax({type:"POST", url: "/_proc/proc_bbsLike.asp",data:params,dataType:"html"
# 				}).done(function(msg){
# 					var msg = msg.split("|")
# 					var retCode = msg[0];
# 					var retMsg = msg[1].replace(/\\n/gi, "\n");
#
# 					if (retCode=="OK"){
# 						location.reload();
# 					}else{
# 						alert(retMsg)
# 					}
# 				});
# 			}
# 		});
# 	});
# 	//-->
# 	</script>
#
# 	<style>
# 	.mBanner.w1278.slider01 img{width:1278px; height:78px}
# 	</style>
#
# 	<!--  LOG corp Web Analitics & Live Chat  START -->
# 	<script type="text/javascript">
# 	//<![CDATA[
# //	function logCorpAScript_full(){
# //		HTTP_MSN_MEMBER_NAME="";/*member name*/
# //		LOGSID = "302472936";/*logsid*/
# //		LOGREF = "";/*logref*/
# //		var prtc=(document.location.protocol=="https:")?"https://":"http://";
# //		var hst=prtc+"asp6.http.or.kr";
# //		var rnd="r"+(new Date().getTime()*Math.random()*9);
# //		this.ch=function(){
# //			if(document.getElementsByTagName("head")[0]){logCorpAnalysis_full.dls();}else{window.setTimeout(logCorpAnalysis_full.ch,30)}
# //		}
# //		this.dls=function(){
# //			var h=document.getElementsByTagName("head")[0];
# //			var s=document.createElement("script");s.type="text/jav"+"ascript";try{s.defer=true;}catch(e){};try{s.async=true;}catch(e){};
# //			if(h){s.src=hst+"/HTTP_MSN/UsrConfig/thinku/js/ASP_Conf.js?s="+rnd;h.appendChild(s);}
# //		}
# //		this.init= function(){
# //			document.write('<img src="'+hst+'/sr.gif?d='+rnd+'" style="width:1px;height:1px;position:absolute;display:none" onload="logCorpAnalysis_full.ch()" alt="" />');
# //		}
# //	}
# //	if(typeof logCorpAnalysis_full=="undefined"){var logCorpAnalysis_full=new logCorpAScript_full();logCorpAnalysis_full.init();}
# 	//]]>
# 	</script>
# 	<noscript><img src="http://asp6.http.or.kr/HTTP_MSN/Messenger/Noscript.php?key=thinku" style="display:none;width:0;height:0;" alt="" /></noscript>
# 	<!-- LOG corp Web Analitics & Live Chat END  -->
#
# 	<script type="text/javascript">
# 	$(window).load(function(){
# 		var data = history.state;
# 		if(data){
# 			$('#contestArea').html(data.list);
# 			var page = data.page;
# 			var serstatus = data.serstatus;
# 			var seritem = data.seritem;
# 			var searchstr = data.searchstr;
# 			var serfield = data.serfield;
# 			var sertarget = data.sertarget;
# 			var serprizeMoney = data.serprizeMoney;
# 			var serdivision = data.serdivision;
#
# 			if (serfield){
# 				for(i = 0; i < serfield.length; i++){
# 					$("input:checkbox[name='serfield']:checkbox[value='"+serfield[i]+"']").attr("checked",true);
# 				}
# 			}
# 			if (sertarget){
# 				for(i = 0; i < sertarget.length; i++){
# 					$("input:checkbox[name='sertarget']:checkbox[value='"+sertarget[i]+"']").attr("checked",true);
# 				}
# 			}
# 			if (serprizeMoney){
# 				for(i = 0; i < serprizeMoney.length; i++){
# 					$("input:checkbox[name='serprizeMoney']:checkbox[value='"+serprizeMoney[i]+"']").attr("checked",true);
# 				}
# 			}
# 			if (serdivision){
# 				for(i = 0; i < serdivision.length; i++){
# 					$("input:checkbox[name='serdivision']:checkbox[value='"+serdivision[i]+"']").attr("checked",true);
# 				}
# 			}
# 			$("form[name=contestAjaxActFrm]>input[name=page]").val( page )
# 			$("form[name=contestAjaxActFrm]>input[name=serstatus]").val( serstatus )
# 			$("form[name=contestAjaxActFrm]>input[name=seritem]").val( seritem )
# 			$("form[name=contestAjaxActFrm]>input[name=searchstr]").val( searchstr )
# 			$("form[name=contestAjaxActFrm]>input[name=serfield]").val( serfield )
# 			$("form[name=contestAjaxActFrm]>input[name=sertarget]").val( sertarget )
# 			$("form[name=contestAjaxActFrm]>input[name=serprizeMoney]").val( serprizeMoney )
# 			$("form[name=contestAjaxActFrm]>input[name=serdivision]").val( serdivision )
# 		}else{
# 			ajaxContestList('', '');
# 		}
#
# 		var vsNum = $(".photo_slider.main .list .slider").length;// 큰거 3개 베너
# 		if(vsNum > 3){
# 			$(".photo_slider.main .list").slick({
# 				autoplay: true,
# 				slidesToShow: 3,
# 				slidesToScroll: 1,
# 				arrows: false,
# 				dots: true
# 			});
# 		}
#
# 		$("body").on("click", ".option input[type=checkbox]", function(){ // 개별취소
# 			/*var optindex = $(".option").index($(this).parents(".option"))
#
# 			if($(this).attr("stat") == "1"){
# 				$(this).attr("stat", "0");
# 				$(this).prop("checked", false);
# 			}else{
# 				$(".option").eq(optindex).find("input[type=checkbox]").attr("stat", "0");
# 				$(this).attr("stat", "1");
# 			}*/
# 			ajaxContestList('searchAction', '1')
# 		});
#
# 		$("body").on("click", ".reset a", function(){ // 전체 취소
# //			$(".option input[type=checkbox]").attr("stat", "0");
# 			$(".option input[type=checkbox]").prop("checked", false);
# 			ajaxContestList('searchAction', '1')
# 		});
#
# 		$("body").on("click", "#searchStrBtn", function(){ // 검색어 검색버튼
# 			var serStr = $("form[name=searchFrm] input[name=searchstr]").val();
# 			var seritem = $("form[name=searchFrm] select[name=seritem]").val();
# 			/*if (serStr==""){
# 				alert("검색어를 입력해주세요.")
# 				return;
# 			}*/
# 			$("form[name=contestAjaxActFrm]>input[name=seritem]").val( seritem );
# 			$("form[name=contestAjaxActFrm]>input[name=searchstr]").val( serStr );
# 			ajaxContestList('searchstring', '1');
# 		});
# 	});
#
# 	function searchStatus(val){
# 		$("form[name=contestAjaxActFrm]>input[name=serstatus]").val( val );
# 		ajaxContestList('searchStatus', '1');
# 	}
#
# 	function ajaxContestList(str, page){
# 		var tObj = $("#contestArea");
# 		var ListUrl = "../contest/ajax_contestList.asp"
# 		if (page!=""){
# 			$("form[name=contestAjaxActFrm]>input[name=page]").val( page );
# 		}
#
# 		var serfield = [], sertarget = [], serprizeMoney = [], serdivision = [];
#
# 		$("input[name='serfield']:checked").each(function(i) {
# 			serfield.push($(this).val());
# 		});
# 		$("input[name='sertarget']:checked").each(function(i) {
# 			sertarget.push($(this).val());
# 		});
# 		$("input[name='serprizeMoney']:checked").each(function(i) {
# 			serprizeMoney.push($(this).val());
# 		});
# 		$("input[name='serdivision']:checked").each(function(i) {
# 			serdivision.push($(this).val());
# 		});
#
# 		$("form[name=contestAjaxActFrm]>input[name=serfield]").val( serfield );
# 		$("form[name=contestAjaxActFrm]>input[name=sertarget]").val( sertarget );
# 		$("form[name=contestAjaxActFrm]>input[name=serprizeMoney]").val( serprizeMoney );
# 		$("form[name=contestAjaxActFrm]>input[name=serdivision]").val( serdivision );
#
# 		if (str=="searchAction"){			// 분야, 대상자별 등 분류 검색시 검색어검색, 상태검색 초기화
# 			$("form[name=contestAjaxActFrm]>input[name=serstatus]").val("");
# 			$("form[name=contestAjaxActFrm]>input[name=seritem]").val( "" );
# 			$("form[name=contestAjaxActFrm]>input[name=searchstr]").val( "" );
# 			$("form[name=searchFrm] input[name=searchstr]").val( "" );
# 		}else if (str=="searchstring"){	// 검색어검색시 상태검색 초기화
# 			$("form[name=contestAjaxActFrm]>input[name=serstatus]").val("");
# 		}
#
# 		var params = $("form[name=contestAjaxActFrm]").serialize();
#
# 		$.ajax({
# 			type:"post",
# 			url: ListUrl,
# 			data:params,
# 			dataType:"html",
# 			async: true
# 		}).done(function(data){
# 			tObj.html(data);
#
# 			if (str=="pageAction"){
# 				moveArea(($("#contestArea").offset().top)-70);
# 			}else if (str=="searchAction" || str=="searchStatus" || str=="searchstring"){
# 				moveArea(($(".detailSearch").offset().top)-60);
# 			}
#
# 			totallist = tObj.html();
# 			serstatus = $("form[name=contestAjaxActFrm]>input[name=serstatus]").val();
# 			page = $("form[name=contestAjaxActFrm]>input[name=page]").val();
# 			seritem = $("form[name=contestAjaxActFrm]>input[name=seritem]").val();
# 			searchstr = $("form[name=contestAjaxActFrm]>input[name=searchstr]").val();
#
# 			history.replaceState({'list':totallist, 'serstatus':serstatus, 'page':page, 'seritem':seritem, 'searchstr':searchstr, 'serfield':serfield, 'sertarget':sertarget, 'serprizeMoney':serprizeMoney, 'serdivision':serdivision},"", window.location.pathname+window.location.search);
# 		})
# 	}
# 	</script>
#
#
#
# <!--[s] Skip To Content -->
# <a href="#contents" class="skip">» 본문 바로가기</a>
# <!--[e] Skip To Content -->
#
# <div id="wrap">
# 		<div id="header"><!-- class="full" -->
# 		<div class="inConts">
# 			<div id="sua">
#
# 				<a href="/member/login.asp"><img src="/images/icon_h_login.png" alt="로그인"><br>로그인</a>
# 				<a href="/member/member.asp"><img src="/images/icon_h_join.png" alt="회원가입"><br>회원가입</a>
#
# 			</div>
#
# 			<form action="/contest/search.asp" name="gbSearchFrm" method="get" onsubmit="MainItemSearchGo(gbSearchFrm); return false;">
# 			<div id="tsch">
# 				<input type="text" name="serstr" id="sk" value="" placeholder="검색어를 입력해주세요">
# 				<input type="submit" value="">
# 			</div>
# 			</form>
#
# 			<div class="logo"><a href="/"><img src="/images/h1_logo.png" alt="씽유"></a></div>
#
# 			<ul id="gnb"><!-- Global Navigation Bar -->
# 									<li class="oPage"><a href="/contest/"><span>공모전/대외활동</span></a>
# 						<ul class="gnbSub">
# 							<li class="oPage"><a href="/contest/"><span>공모전/대외활동</span></a></li>
# 							<li><a href="/recm_contest/"><span>씽유추천! 공모전</span></a></li>
# 							<li><a href="/recm_activity/"><span>씽유추천! 대외활동</span></a></li>
# 						</ul>
# 					</li>
# 					<li><a href="/contestplus/"><span>공모전 더하기</span></a>
# 						<ul class="gnbSub">
# 							<li class="mo"><a href="/contestplus/"><span>모아보기</span></a></li>
# 							<li><a href="/intv_org/"><span>주최사 인터뷰</span></a></li>
# 							<li><a href="/intv_winner/"><span>수상자 인터뷰</span></a></li>
# 							<li><a href="/gallery/"><span>수상작 갤러리</span></a></li>
# 						</ul>
# 					</li>
# 					<li><a href="/campus/"><span>캠퍼스 플러스</span></a>
# 						<ul class="gnbSub">
# 							<li class="mo"><a href="/campus/"><span>모아보기</span></a></li>
# 							<li><a href="/cover/"><span>커버 인터뷰</span></a></li>
# 							<li><a href="/mentor/"><span>찾았다 인생 멘토</span></a></li>
# 							<li><a href="/issue/"><span>캠퍼스 이슈 토크</span></a></li>
# 							<li><a href="/wise/"><span>슬기로운 대학 생활</span></a></li>
# 							<li><a href="/note/"><span>취업 합격 노트</span></a></li>
# 							<li><a href="/job/"><span>슬기로운 인담생활</span></a></li>
# 						</ul>
# 					</li>
# 					<li><a href="/eventMain/"><span>이벤트</span></a>
# 						<ul class="gnbSub">
# 							<li class="mo"><a href="/eventMain/"><span>모아보기</span></a></li>
# 							<li><a href="/event/"><span>전시·공연</span></a></li>
# 							<li><a href="/eventThink/"><span>씽유 이벤트</span></a></li>
# 						</ul>
# 					</li>
# 			</ul>
#
# 			<ul id="utill">
# 				<li><a href="/sub/banner.asp"><span>배너광고 안내</span></a></li>
# 				<li><a href="/sub/proxy.asp"><span>공모전 대행안내</span></a></li>
# 				<li><a href="/sub/free.asp"><span>공모전 무료 등록</span></a></li>
# 				<li><a href="/faq/"><span>자주묻는질문</span></a></li>
# 			</ul>
# 		</div>
# 	</div>
#
# 	<div id="container" class="landscape">
# 				<div id="snb"><!-- Side Navigation Bar -->
# 			<ul id="nav"><!-- Navigation -->
# 				<script type="text/javascript">
# 					var pgCode = $("body").attr("data-pgCode");
# 					if(pgCode){
# 						leftMenuList(pgCode);
# 					}
# 				</script><li class="sMenu sDepth01"><a href="javascript:void(0);"><span>공모전/대외활동</span><i></i></a><div class="lnbSub"><a href="javascript:link0101();" class="active"><span>공모전/대외활동</span></a><a href="javascript:link0200();" class=""><span>공모전 더하기</span></a><a href="javascript:link0300();" class=""><span>캠퍼스 플러스</span></a><a href="javascript:link0401();" class=""><span>이벤트</span></a><a href="javascript:link0501();" class=""><span>자주묻는질문</span></a></div></li><li class="sMenu sDepth02"><a href="javascript:void(0);"><span>공모전/대외활동</span><i></i></a><div class="lnbSub"><a href="javascript:link0101();" class="active"><span>공모전/대외활동</span></a><a href="javascript:link0102();" class=""><span>씽유추천! 공모전</span></a><a href="javascript:link0103();" class=""><span>씽유추천! 대외활동</span></a></div></li>
# 			</ul>
# 		</div>
# 		<div id="pageTop" class="open">
# 			<h1>공모전/대외활동</h1>
# 			<div class="pageNavi"><span class="home">Home</span><span>공모전/대외활동</span><span class="last">공모전/대외활동</span></div>
# 		</div>
#
# 		<div id="contents" class="open"><!-- 내용 -->
# 			<div class="contestTop">
# 				<div class="photo_slider main card three"><!-- 메인 리스트 -->
# 					<h2 class="bul">공모전 HOT</h2>
# 					<div class="list slick-initialized slick-slider slick-dotted"><div class="slick-list draggable"><div class="slick-track" style="opacity: 1; width: 13975px; transform: translate3d(-975px, 0px, 0px);"><div class="slick-slide slick-cloned" data-slick-index="-3" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/22997'" class="banLog" dataid="2683" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제4회 유니버설디자인 아이디어 대전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x4007.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.07.25 ~ 2022.07.29 ( D-81 )</p>
# 			<p class="title">제4회 유니버설디자인 아이디어 대전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="-2" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23027'" class="banLog" dataid="2688" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제9회 산업안전보건 조사자료 논문 경진대회" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x4008.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.03.07 ~ 2022.06.19 ( D-45 )</p>
# 			<p class="title">제9회 산업안전보건 조사자료 논문 경진대회</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="-1" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23906/'" class="banLog" dataid="2788" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제3회 개별협력실증연구 대학원생 연구제안서 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40019.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.14 ~ 2022.06.30 ( D-56 )</p>
# 			<p class="title">제3회 개별협력실증연구 대학원생 연구제안서 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-current slick-active" data-slick-index="0" aria-hidden="false" role="tabpanel" id="slick-slide00" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24090'" class="banLog" dataid="2809" style="cursor:pointer;" tabindex="0">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 ‘성희롱 없는 일터 만들기’ 에세이 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40010.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.25 ~ 2022.06.27 ( D-53 )</p>
# 			<p class="title">2022 ‘성희롱 없는 일터 만들기’ 에세이 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-active" data-slick-index="1" aria-hidden="false" role="tabpanel" id="slick-slide01" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23790'" class="banLog" dataid="2779" style="cursor:pointer;" tabindex="0">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제14회 독립기념관 UCC 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40011.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.11 ~ 2022.06.30 ( D-56 )</p>
# 			<p class="title">제14회 독립기념관 UCC 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-active" data-slick-index="2" aria-hidden="false" role="tabpanel" id="slick-slide02" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23964'" class="banLog" dataid="2797" style="cursor:pointer;" tabindex="0">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제20회 김해시 도시경관디자인 작품공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/메인배너0.png&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.07.04 ~ 2022.07.29 ( D-60 )</p>
# 			<p class="title">제20회 김해시 도시경관디자인 작품공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="3" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide03" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24326/'" class="banLog" dataid="2823" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="크리에이터가 만드는 디지털서울 NFT 챌린지" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/[크기변환]_11디지털서울-NFT챌린지-홍보-포스터.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.05.02 ~ 2022.06.20 ( D-46 )</p>
# 			<p class="title">크리에이터가 만드는 디지털서울 NFT 챌린지</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="4" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide04" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23990'" class="banLog" dataid="2807" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="(주)정직한도움 완성창 유튜브 UCC 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/정직한도움공모전포스터305_400-001_(1).png&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.20 ~ 2022.06.20 ( D-46 )</p>
# 			<p class="title">(주)정직한도움 완성창 유튜브 UCC 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="5" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide05" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23546'" class="banLog" dataid="2751" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제31회 국립서울현충원 호국문예 백일장/제17회 그림 그리기&nbsp;대회 안내" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/호국문예-백일장.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.01 ~ 2022.05.18 ( D-13 )</p>
# 			<p class="title">제31회 국립서울현충원 호국문예 백일장/제17회 그림 그리기&nbsp;대회 안내</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="6" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide06" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24007'" class="banLog" dataid="2803" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제2회 해양조사의 날 안전海 사진 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40021.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.20 ~ 2022.06.03 ( D-29 )</p>
# 			<p class="title">제2회 해양조사의 날 안전海 사진 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="7" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide07" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24108'" class="banLog" dataid="2812" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제 4회 2022 INFINeLI 디자인 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/22_INFINeLI_banner__305x400.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.07.25 ~ 2022.08.01 ( D-81 )</p>
# 			<p class="title">제 4회 2022 INFINeLI 디자인 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="8" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide08" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23905'" class="banLog" dataid="2836" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 대학생 제품안전 홍보단 모집 안내" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/제품안전_홍보단_배너(씽유_업로드).png&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.18 ~ 2022.05.06 ( D-1 )</p>
# 			<p class="title">2022 대학생 제품안전 홍보단 모집 안내</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="9" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide09" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23851/'" class="banLog" dataid="2801" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022년 제16회 빛공해 사진 · UCC 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/빛공해.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.18 ~ 2022.06.24 ( D-50 )</p>
# 			<p class="title">2022년 제16회 빛공해 사진 · UCC 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="10" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide010" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24331'" class="banLog" dataid="2826" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="캠퍼스플러스 28기 학생기자 모집" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40020.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.05.02 ~ 2022.05.29 ( D-24 )</p>
# 			<p class="title">캠퍼스플러스 28기 학생기자 모집</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="11" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide011" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23954'" class="banLog" dataid="2793" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 단양관광 UCC·사진 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/단양-영상-공모전.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.20 ~ 2022.11.03 ( D-182 )</p>
# 			<p class="title">2022 단양관광 UCC·사진 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="12" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide012" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23838'" class="banLog" dataid="2785" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022년 국립공원 생태탐방원 생태관광 상품 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40018.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.14 ~ 2022.05.25 ( D-20 )</p>
# 			<p class="title">2022년 국립공원 생태탐방원 생태관광 상품 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="13" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide013" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23960'" class="banLog" dataid="2799" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 대중교통 아이디어 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/220419_[티머니복지재단]_씽유_305x400px_대중교통_아이디어_공모전.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.29 ~ 2022.05.20 ( D-15 )</p>
# 			<p class="title">2022 대중교통 아이디어 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="14" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide014" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23335'" class="banLog" dataid="2733" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022년 독립기념관 ‘내가 찍은 봄’ 사진공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40013.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.03.23 ~ 2022.05.31 ( D-26 )</p>
# 			<p class="title">2022년 독립기념관 ‘내가 찍은 봄’ 사진공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="15" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide015" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/22968'" class="banLog" dataid="2672" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="LG유플러스 아이들나라 창작 그림책 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/lguplus.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.03.02 ~ 2022.05.31 ( D-26 )</p>
# 			<p class="title">LG유플러스 아이들나라 창작 그림책 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="16" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide016" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24296'" class="banLog" dataid="2830" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022년 『제15회 잡지 미디어 콘텐츠 공모전- 잡지가 있는 삶』" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40022.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.05.02 ~ 2022.08.31 ( D-118 )</p>
# 			<p class="title">2022년 『제15회 잡지 미디어 콘텐츠 공모전- 잡지가 있는 삶』</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="17" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide017" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/22997'" class="banLog" dataid="2683" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제4회 유니버설디자인 아이디어 대전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x4007.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.07.25 ~ 2022.07.29 ( D-81 )</p>
# 			<p class="title">제4회 유니버설디자인 아이디어 대전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="18" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide018" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23027'" class="banLog" dataid="2688" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제9회 산업안전보건 조사자료 논문 경진대회" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x4008.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.03.07 ~ 2022.06.19 ( D-45 )</p>
# 			<p class="title">제9회 산업안전보건 조사자료 논문 경진대회</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide" data-slick-index="19" aria-hidden="true" tabindex="-1" role="tabpanel" id="slick-slide019" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23906/'" class="banLog" dataid="2788" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제3회 개별협력실증연구 대학원생 연구제안서 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40019.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.14 ~ 2022.06.30 ( D-56 )</p>
# 			<p class="title">제3회 개별협력실증연구 대학원생 연구제안서 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="20" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24090'" class="banLog" dataid="2809" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 ‘성희롱 없는 일터 만들기’ 에세이 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40010.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.25 ~ 2022.06.27 ( D-53 )</p>
# 			<p class="title">2022 ‘성희롱 없는 일터 만들기’ 에세이 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="21" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23790'" class="banLog" dataid="2779" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제14회 독립기념관 UCC 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40011.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.11 ~ 2022.06.30 ( D-56 )</p>
# 			<p class="title">제14회 독립기념관 UCC 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="22" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23964'" class="banLog" dataid="2797" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제20회 김해시 도시경관디자인 작품공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/메인배너0.png&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.07.04 ~ 2022.07.29 ( D-60 )</p>
# 			<p class="title">제20회 김해시 도시경관디자인 작품공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="23" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24326/'" class="banLog" dataid="2823" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="크리에이터가 만드는 디지털서울 NFT 챌린지" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/[크기변환]_11디지털서울-NFT챌린지-홍보-포스터.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.05.02 ~ 2022.06.20 ( D-46 )</p>
# 			<p class="title">크리에이터가 만드는 디지털서울 NFT 챌린지</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="24" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23990'" class="banLog" dataid="2807" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="(주)정직한도움 완성창 유튜브 UCC 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/정직한도움공모전포스터305_400-001_(1).png&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.20 ~ 2022.06.20 ( D-46 )</p>
# 			<p class="title">(주)정직한도움 완성창 유튜브 UCC 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="25" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23546'" class="banLog" dataid="2751" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제31회 국립서울현충원 호국문예 백일장/제17회 그림 그리기&nbsp;대회 안내" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/호국문예-백일장.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.01 ~ 2022.05.18 ( D-13 )</p>
# 			<p class="title">제31회 국립서울현충원 호국문예 백일장/제17회 그림 그리기&nbsp;대회 안내</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="26" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24007'" class="banLog" dataid="2803" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제2회 해양조사의 날 안전海 사진 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40021.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.20 ~ 2022.06.03 ( D-29 )</p>
# 			<p class="title">제2회 해양조사의 날 안전海 사진 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="27" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24108'" class="banLog" dataid="2812" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="제 4회 2022 INFINeLI 디자인 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/22_INFINeLI_banner__305x400.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.07.25 ~ 2022.08.01 ( D-81 )</p>
# 			<p class="title">제 4회 2022 INFINeLI 디자인 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="28" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23905'" class="banLog" dataid="2836" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 대학생 제품안전 홍보단 모집 안내" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/제품안전_홍보단_배너(씽유_업로드).png&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.18 ~ 2022.05.06 ( D-1 )</p>
# 			<p class="title">2022 대학생 제품안전 홍보단 모집 안내</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="29" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23851/'" class="banLog" dataid="2801" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022년 제16회 빛공해 사진 · UCC 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/빛공해.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.18 ~ 2022.06.24 ( D-50 )</p>
# 			<p class="title">2022년 제16회 빛공해 사진 · UCC 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="30" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/24331'" class="banLog" dataid="2826" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="캠퍼스플러스 28기 학생기자 모집" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40020.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.05.02 ~ 2022.05.29 ( D-24 )</p>
# 			<p class="title">캠퍼스플러스 28기 학생기자 모집</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="31" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23954'" class="banLog" dataid="2793" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 단양관광 UCC·사진 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/단양-영상-공모전.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.20 ~ 2022.11.03 ( D-182 )</p>
# 			<p class="title">2022 단양관광 UCC·사진 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="32" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23838'" class="banLog" dataid="2785" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022년 국립공원 생태탐방원 생태관광 상품 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40018.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.14 ~ 2022.05.25 ( D-20 )</p>
# 			<p class="title">2022년 국립공원 생태탐방원 생태관광 상품 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="33" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23960'" class="banLog" dataid="2799" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022 대중교통 아이디어 공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/220419_[티머니복지재단]_씽유_305x400px_대중교통_아이디어_공모전.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.04.29 ~ 2022.05.20 ( D-15 )</p>
# 			<p class="title">2022 대중교통 아이디어 공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="34" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# 	<a onclick="location.href='https://thinkyou.co.kr/contest/23335'" class="banLog" dataid="2733" style="cursor:pointer;" tabindex="-1">
# 		<div class="thumb"><img src="/images/blank.gif" class="bg_thumb" alt="2022년 독립기념관 ‘내가 찍은 봄’ 사진공모전" style="background-size: cover; width: 100%; max-width: 9999px; height: 100%; background-image: url(&quot;/upload/mainbanner/씽유메인_305x40013.jpg&quot;);"><span class="bg"></span></div>
# 		<div class="area"><div class="in_area">
# 			<p class="day">2022.03.23 ~ 2022.05.31 ( D-26 )</p>
# 			<p class="title">2022년 독립기념관 ‘내가 찍은 봄’ 사진공모전</p>
# 		</div></div>
# 	</a>
# </div></div></div><div class="slick-slide slick-cloned" data-slick-index="35" aria-hidden="true" tabindex="-1" style="width: 325px;"><div><div class="slider" style="width: 100%; display: inline-block;">
# ...
# 				<dd>주최 : 예천군, 예천낭독연구회&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-05-01 ~ 22-07-31</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-87</div>
# 	<div class="etc">852</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24207/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>제32회 구상솟대문학상 </h3></dt>
# 				<dd>주최 : 한국장애인예술인협회&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-06-20 ~ 22-06-30</div>
# 	<div class="statNew"><p class="icon schedule">접수예정</p>D-46</div>
# 	<div class="etc">775</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24203/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 과학 슬기 공모전 (항공우주편) </h3></dt>
# 				<dd>주최 : 국립중앙과학관&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-05-23 ~ 22-06-06</div>
# 	<div class="statNew"><p class="icon schedule">접수예정</p>D-18</div>
# 	<div class="etc">1064</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24221/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 지식재산 스타트업 경진대회 </h3></dt>
# 				<dd>주최 : 특허청&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-12 ~ 22-05-31</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-26</div>
# 	<div class="etc">828</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24156/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>제13회 백교문학상 작품공모 </h3></dt>
# 				<dd>주최 : (재)강릉문화재단, (사)백교효문화선양회&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-13 ~ 22-05-31</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-26</div>
# 	<div class="etc">882</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24158/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022년 제24회 수주문학상 공모 </h3></dt>
# 				<dd>주최 : 부천문화재단&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-06-13 ~ 22-07-01</div>
# 	<div class="statNew"><p class="icon schedule">접수예정</p>D-39</div>
# 	<div class="etc">1151</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24138/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>인공지능 사관학교 3기 교육생 2차 모집 </h3></dt>
# 				<dd>주최 : (사)스마트인재개발원&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-13 ~ 22-05-06</div>
# 	<div class="statNew"><p class="icon deadline">마감임박</p>D-1</div>
# 	<div class="etc">1005</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24037/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 날씨빅데이터 콘테스트 </h3></dt>
# 				<dd>주최 : 기상청&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-25 ~ 22-05-30</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-25</div>
# 	<div class="etc">1104</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/24016/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>K-이노스 창업아이디어 경진대회 </h3></dt>
# 				<dd>주최 : 건국대학교 캠퍼스타운&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-04 ~ 22-05-08</div>
# 	<div class="statNew"><p class="icon deadline">마감임박</p>D-3</div>
# 	<div class="etc">917</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23996/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 식의약 데이터 활용 경진대회 </h3></dt>
# 				<dd>주최 : 식품의약품안전처&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-20 ~ 22-06-19</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-45</div>
# 	<div class="etc">1087</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23994/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>제26회 한국해양문학상 작품 공모 </h3></dt>
# 				<dd>주최 : 부산광역시문인협회&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-13 ~ 22-06-24</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-50</div>
# 	<div class="etc">1001</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23984/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>[2022 레드브릭 메타버스 챌린지] 주니어 소프트웨어 창작 공모전 </h3></dt>
# 				<dd>주최 : (주)레드브릭&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-18 ~ 22-05-29</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-24</div>
# 	<div class="etc">922</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23959/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>'2022 김해시 올해의 책' 독후감 전국 공모전 </h3></dt>
# 				<dd>주최 : 김해시&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-18 ~ 22-09-16</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-134</div>
# 	<div class="etc">1069</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23958/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 제3회 이형기 디카시신인문학상 공모전 </h3></dt>
# 				<dd>주최 : 진주시&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-16 ~ 22-05-15</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-10</div>
# 	<div class="etc">984</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23957/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 심훈문학상 </h3></dt>
# 				<dd>주최 : 사단법인 심훈선생기념사업회&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-01-01 ~ 22-05-30</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-25</div>
# 	<div class="etc">887</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23955/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>제18회 나라사랑 체험소감문 공모전 </h3></dt>
# 				<dd>주최 : 국립대전현충원&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-01 ~ 22-10-31</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-179</div>
# 	<div class="etc">994</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23952/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>제1회 럭스로보 메타버스 지능로봇 경진대회 </h3></dt>
# 				<dd>주최 : 럭스로보&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-18 ~ 22-06-07</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-33</div>
# 	<div class="etc">979</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23942/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>네트워크 지능화를 위한 인공지능 해커톤 </h3></dt>
# 				<dd>주최 : 한국전자통신연구원 (ETRI)&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-18 ~ 22-05-13</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-8</div>
# 	<div class="etc">804</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23909/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 현대오토에버 배리어프리 앱개발 콘테스트 </h3></dt>
# 				<dd>주최 : 현대오토에버&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-18 ~ 22-05-20</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-15</div>
# 	<div class="etc">1173</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23938/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022년 노인일자리사업 대국민 아이디어 공모전 </h3></dt>
# 				<dd>주최 : 한국노인인력개발원&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-18 ~ 22-05-31</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-26</div>
# 	<div class="etc">1106</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23931/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022년 텐서플로우를 활용한 인공지능 데이터 분석 과정 교육생 모집 </h3></dt>
# 				<dd>주최 : 한국여성과학기술인육성재단&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-15 ~ 22-05-09</div>
# 	<div class="statNew"><p class="icon deadline">마감임박</p>D-4</div>
# 	<div class="etc">1084</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23815/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 세계 기초과학의 해, 과학콘텐츠 공모전 </h3></dt>
# 				<dd>주최 : 한국기초과학지원연구원&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-04-13 ~ 22-05-10</div>
# 	<div class="statNew"><p class="icon deadline">마감임박</p>D-5</div>
# 	<div class="etc">1105</div>
# </div>
# <div class="tr ">
# 	<div class="title">
# 		<a href="/contest/23819/?page=1&amp;pagesize=35&amp;serstatus=&amp;serdivision=&amp;serfield=5&amp;sertarget=&amp;serprizeMoney=&amp;seritem=0&amp;searchstr=">
# 			<dl>
# 				<dt><h3>2022 SF 오디오 스토리 어워즈 </h3></dt>
# 				<dd>주최 : 밀리의 서재 x 다산북스&nbsp;</dd>
# 			</dl>
# 		</a>
# 	</div>
# 	<div class="etc">22-03-03 ~ 22-05-30</div>
# 	<div class="statNew"><p class="icon receiving">접수중</p>D-25</div>
# 	<div class="etc">898</div>
# </div>
#
# 	</div>
# </div>
# <!--[e] List -->
#
# <div class="paging_all full">
# <a class="btn prev2">처음</a>
# <a href="#noLink" class="btn prev">이전</a>
# <span class="num">
# <strong>1</strong>
# <a href="javascript:ajaxContestList('pageAction','2')">2</a>
# <a href="javascript:ajaxContestList('pageAction','3')">3</a>
# <a href="javascript:ajaxContestList('pageAction','4')">4</a>
# <a href="javascript:ajaxContestList('pageAction','5')">5</a>
# <a href="javascript:ajaxContestList('pageAction','6')">6</a>
# <a href="javascript:ajaxContestList('pageAction','7')">7</a>
# <a href="javascript:ajaxContestList('pageAction','8')">8</a>
# <a href="javascript:ajaxContestList('pageAction','9')">9</a>
# <a href="javascript:ajaxContestList('pageAction','10')">10</a>
# </span>
# <a href="javascript:ajaxContestList('pageAction','2')" class="btn next">다음</a>
# <a href="javascript:ajaxContestList('pageAction','25')" class="btn next2">끝</a>
# </div>
# </div>
#
# 			</div>
# 		</div>
# 	</div>
#
# 		<div id="footer">
# 		<div class="inConts">
# 			<div class="link">
# 				<div class="txt">
# 					<a href="https://thinkyou.co.kr/">공모전 </a>
# 					<a href="/sub/about.asp">씽유소개 </a>
# 					<a href="/etc/privacy.asp">개인정보취급방침</a>
# 					<a href="/etc/email.asp">이메일 무단수집거부</a>
# 					<a href="/etc/alliance.asp">제휴안내</a>
# 					<!-- <a href="javascript:void(0);">사이트맵</a> -->
# 				</div>
# 				<div class="social">
# 					<a href="https://www.facebook.com/thinkyou.co.kr" target="_blank"><img src="/images/btn_f_facebook.png" alt="facebook"></a>
# 					<a href="https://blog.naver.com/thinku1125" target="_blank"><img src="/images/btn_f_blog.png" alt="blog"></a>
# 					<a href="https://www.youtube.com/c/thinkyoutube" target="_blank"><img src="/images/btn_f_youtube.png" alt="youtube"></a>
# 				</div>
# 			</div>
#
# 			<div class="text">
# 				<p class="tit"><span class="point">(주)인투인미디어</span><span>문의 및 요청 : <b class="point">mail@intoinmedia.com</b></span></p>
# 				<p><span>전화: 02-2233-<b class="point">4016 (공모전 등록, 배너광고 문의)</b></span><span> 02-2233-<b class="point">3925 (공모전 대행 문의)</b></span></p>
# 				<p><span>사업자등록번호 : 201-86-21825</span><span>직업정보제공사업신고번호 : J1204220140006</span></p>
# 				<p><span>대표이사 : 문기숙  </span><span>주소 : 서울시 영등포구 양평로 21길 26 1203호</span></p>
# 				<!-- <address>COPYRIGHT &copy; 2020 <span>thinkyou.co.kr</span>. ALL RIGHTS RESERVED.</address> -->
# 				<div class="quick">
# 					<a href="/sub/banner.asp"><img src="/images/icon_f_02.png" alt="배너광고 안내"><p>배너광고 안내</p></a>
# 					<a href="/sub/proxy.asp"><img src="/images/icon_f_03.png" alt="공모전 대행안내"><p>공모전 대행안내</p></a>
# 					<a href="/sub/estimate.asp"><img src="/images/icon_f_04.png" alt="공모전 견적요청"><p>공모전 견적요청</p></a>
# 					<a href="/sub/free.asp"><img src="/images/icon_f_01.png" alt="공모전 무료 등록"><p>공모전 무료 등록</p></a>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div id="quickArea">
# 		<p><img src="/images/tit_quick.png" alt="QUICK MENU"></p>
# 		<ul>
# 			<li><a href="https://www.facebook.com/thinkyou.co.kr" target="_blank"><img src="/images/btn_quick01.gif" alt="페이스북"></a></li>
# 			<li><a href="https://blog.naver.com/thinku1125" target="_blank"><img src="/images/btn_quick02.gif" alt="블로그"></a></li>
# 			<li><a href="https://www.youtube.com/c/thinkyoutube" target="_blank"><img src="/images/qBtn_youtube.gif" alt="YOUTUBE"></a></li>
# 			<li><a href="javascript:openLay('newsletter');"><img src="/images/btn_quick03.gif" alt="뉴스레터"></a></li>
# 			<li><a href="http://www.campl.co.kr/default.asp" target="_blank"><img src="/images/btn_quick04.gif" alt="캠퍼스플러스"></a></li>
# 		</ul>
# 		<a href="javascript:void(0);" class="goTop"><img src="/images/btn_goTop.gif" alt="TOP"></a>
# 	</div>
#
# <!--[s] Layer -->
# <div class="layerArea"><div class="layerIn"><div class="layerCell">
# 	<div class="layerBox newsletter">
# 		<a href="javascript:void(0);" class="closeLy"><img src="/images/btn_lay_close.png" alt="닫기"></a>
# 		<div class="tit">뉴스레터 신청</div>
#
# 		<div class="contLy">
# 			<p class="txt">
# 				씽유 뉴스레터 신청을 위해 아래에 이메일 주소를 기입해주세요. <br>
# 				공모전 / 대외활동 / 이벤트 소식을 전달해드립니다.
# 			</p>
# 			<form name="newsletterFrm" id="newsletterFrm" method="post">
# 			<div class="form">
# 				<input type="text" name="email" maxlength="25" value="">
# 				<span>@</span>
# 				<input type="text" class="eDomain" name="email" maxlength="25" value="">
# 				<select class="eDomailSelector">
# 					<option value="" selected="">직접입력</option>
# 					<option value="naver.com">naver.com</option>
# <option value="hanmail.net">hanmail.net</option>
# <option value="gmail.com">gmail.com</option>
# <option value="daum.net">daum.net</option>
# <option value="nate.com">nate.com</option>
#
# 				</select>
# 			</div>
# 			</form>
#
# 			<div class="btnArea tac">
# 				<a href="javascript:newsLetterSend();">뉴스레터 신청</a>
# 			</div>
# 		</div>
#
# 	</div>
# </div><div class="layerBgIn"></div></div></div>
# <!--[e] Layer -->
#
#
#
# <script type="text/javascript" src="//wcs.naver.net/wcslog.js"></script>
# <script type="text/javascript">
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "fff9f7a878b278";
# if(window.wcs) {
#   wcs_do();
# }
# </script>
# </div>
#
# <p class="testText"></p><div id="simplemodal_div" style="display: none;"><span id="simplemodal-placeholder" style="display: none;"></span></div><div id="simplemodal-overlay" class="simplemodal-overlay" style="opacity: 0.5; height: 4627px; width: 2543px; position: fixed; left: 0px; top: 0px; z-index: 20001; background: none;"></div><div id="simplemodal-container" class="simplemodal-container" style="position: fixed; z-index: 20002; height: auto; width: auto; left: 1271.5px; top: 642px;"><div tabindex="-1" class="simplemodal-wrap" style="height: 100%; outline: 0px; width: 100%; overflow: visible;"><span id="simplemodal_span" class="simplemodal-data" style=""><div class="loading"><img src="/images/loading.gif" alt="Loading"></div></span></div></div></body></html>

# %%
len_day = 20

links_bef = []
titles_bef = []
dday_bef = []
inst_bef = []
start_bef = []
end_bef = []

links_aft = []
titles_aft = []
inst_aft = []
base_url = 'https://thinkyou.co.kr'

for i in range(len_day):
    t = soup.select(' .title > a > dl > dt ')[i].text
    fin = soup.select(' .statNew > p ')[i].text


    if fin == '마감':  
        titles_aft.append(soup.select(' .title > a > dl > dt ')[i].text)
        inst_aft.append(soup.select(' .title > a > dl > dd ')[i].text.split(':')[1][1:])

        links_aft.append(base_url + soup.select(' .title > a')[i]['href'][2:])
    else:
        stand = soup.select(' .statNew')[i].text.split('D')[1]


        if stand == '-day':
            num = 0
            titles_bef.append(soup.select(' .title > a > dl > dt ')[i].text)
            inst_bef.append(soup.select(' .title > a > dl > dd ')[i].text.split(':')[1][1:])
            dday_bef.append(num)
            links_bef.append(base_url + soup.select(' .title > a')[i]['href'][2:])
            a = i * 2
            start_bef.append(soup.select(' .etc')[a].text[:8])
            end_bef.append(soup.select(' .etc')[a].text[11:])

        else:
            titles_bef.append(soup.select(' .title > a > dl > dt ')[i].text)
            inst_bef.append(soup.select(' .title > a > dl > dd ')[i].text.split(':')[1][1:])
            dday_bef.append(soup.select(' .statNew')[i].text.split('-')[1])
            links_bef.append(base_url + soup.select(' .title > a')[i]['href'][2:])
            a = i * 2
            start_bef.append(soup.select(' .etc')[a].text[:8])
            end_bef.append(soup.select(' .etc')[a].text[11:])
                
print(inst_bef)

tabl_data_bef = {'title': titles_bef, 'notice': start_bef, 'deadline': end_bef, 
                     'dday': dday_bef, 'sponsor': inst_bef, 'title2': titles_bef, 'link': links_bef}
print(tabl_data_bef)

df_bef = pd.DataFrame(tabl_data_bef, columns=['type', 'qualification', 'title', 
                                                  'notice', 'deadline', 'dday', 'sponsor', 'title2', 'link'])
    
df_bef['type'] = '2 공모전'
    
    
df_bef['qualification'] = '대학(원)생'
# Out:
# ['LH 한국토지주택공사\xa0', '통계청\xa0', '방송통신위원회, 한국인터넷진흥원\xa0', '방위사업청, 대전광역시\xa0', '선문대학교 산학협력단\xa0', '데이콘\xa0', '한국과학창의재단\xa0', 'SK하이닉스\xa0', '사단법인 한국문인협회 평택지부\xa0', '영남대학교\xa0', '고용노동부\xa0', '고용노동부\xa0', '예천군, 예천낭독연구회\xa0', '한국장애인예술인협회\xa0', '국립중앙과학관\xa0', '특허청\xa0', '(재)강릉문화재단, (사)백교효문화선양회\xa0', '부천문화재단\xa0', '(사)스마트인재개발원\xa0', '기상청\xa0']
# {'title': ['부천대장 공공주택 대국민 아이디어 공모전  ', '제24회 전국학생 통계활용대회  ', '2022년 위치정보 우수비즈니스 모델 발굴 프로젝트 위치기반서비스 공모전 & 클라우드 인프라 지원 사업  ', '[미래도전국방기술 경진대회]전장상황에서의 자율비행 기술경진대회Ⅲ  ', '자동차 인증 교육(안전 및 환경 규제에 대한 인증) 교육생 모집 ', '데이콘 소비자 데이터 기반 소비 예측 경진대회 ', '제4회 SW·AI 수업 우수사례 공모전 ', '사회문제 해결 스타트업 아이디어 공모전 ', '제29회 평택사랑 전국백일장 공모전 ', '2022 스마트물류 공모전 ', '2022년 K-디지털 트레이닝 해커톤 ', '[고용노동부] K-Digital Training 국내 유일 의료·바이오 AI 융합인재 취업연계 ', '제4회 예천내성천문예현상 공모전 ', '제32회 구상솟대문학상 ', '2022 과학 슬기 공모전 (항공우주편) ', '2022 지식재산 스타트업 경진대회 ', '제13회 백교문학상 작품공모 ', '2022년 제24회 수주문학상 공모 ', '인공지능 사관학교 3기 교육생 2차 모집 ', '2022 날씨빅데이터 콘테스트 '], 'notice': ['22-05-04', '22-05-02', '22-05-09', '22-05-12', '22-04-29', '22-05-02', '22-04-18', '22-05-02', '22-04-25', '22-04-16', '22-04-26', '22-04-26', '22-05-01', '22-06-20', '22-05-23', '22-04-12', '22-04-13', '22-06-13', '22-04-13', '22-04-25'], 'deadline': ['22-05-17', '22-06-17', '22-06-17', '22-05-25', '22-06-17', '22-05-13', '22-06-17', '22-06-06', '22-05-25', '22-05-19', '22-05-13', '22-07-03', '22-07-31', '22-06-30', '22-06-06', '22-05-31', '22-05-31', '22-07-01', '22-05-06', '22-05-30'], 'dday': ['12', '43', '4', '7', '43', '8', '43', '32', '20', '14', '8', '59', '87', '46', '18', '26', '26', '39', '1', '25'], 'sponsor': ['LH 한국토지주택공사\xa0', '통계청\xa0', '방송통신위원회, 한국인터넷진흥원\xa0', '방위사업청, 대전광역시\xa0', '선문대학교 산학협력단\xa0', '데이콘\xa0', '한국과학창의재단\xa0', 'SK하이닉스\xa0', '사단법인 한국문인협회 평택지부\xa0', '영남대학교\xa0', '고용노동부\xa0', '고용노동부\xa0', '예천군, 예천낭독연구회\xa0', '한국장애인예술인협회\xa0', '국립중앙과학관\xa0', '특허청\xa0', '(재)강릉문화재단, (사)백교효문화선양회\xa0', '부천문화재단\xa0', '(사)스마트인재개발원\xa0', '기상청\xa0'], 'title2': ['부천대장 공공주택 대국민 아이디어 공모전  ', '제24회 전국학생 통계활용대회  ', '2022년 위치정보 우수비즈니스 모델 발굴 프로젝트 위치기반서비스 공모전 & 클라우드 인프라 지원 사업  ', '[미래도전국방기술 경진대회]전장상황에서의 자율비행 기술경진대회Ⅲ  ', '자동차 인증 교육(안전 및 환경 규제에 대한 인증) 교육생 모집 ', '데이콘 소비자 데이터 기반 소비 예측 경진대회 ', '제4회 SW·AI 수업 우수사례 공모전 ', '사회문제 해결 스타트업 아이디어 공모전 ', '제29회 평택사랑 전국백일장 공모전 ', '2022 스마트물류 공모전 ', '2022년 K-디지털 트레이닝 해커톤 ', '[고용노동부] K-Digital Training 국내 유일 의료·바이오 AI 융합인재 취업연계 ', '제4회 예천내성천문예현상 공모전 ', '제32회 구상솟대문학상 ', '2022 과학 슬기 공모전 (항공우주편) ', '2022 지식재산 스타트업 경진대회 ', '제13회 백교문학상 작품공모 ', '2022년 제24회 수주문학상 공모 ', '인공지능 사관학교 3기 교육생 2차 모집 ', '2022 날씨빅데이터 콘테스트 '], 'link': ['https://thinkyou.co.krontest/24443/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24427/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24464/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24459/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24280/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24290/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24275/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24300/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24243/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24256/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24259/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24184/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.krontest/24205/?page=1&pagesize=35&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=', ' ...

# %%
def sort_contest():
    you = crawling()
    good = browser2()
    incruit=final_incruit()
    contest = pd.concat([you, good, incruit])
    contest_df = contest.reset_index(drop=True)
    contest_df['title'] = contest_df['title'].str.strip()
    contest_mid = contest_df.drop_duplicates(['title'], keep='first')
    contest_mid2 = contest_mid.reset_index(drop = True)
    contest_mid2['dday'] = contest_mid2['dday'].astype(int)
    contest_fin = contest_mid2.sort_values(by ='dday')
    final = contest_fin.reset_index(drop = True)
    
    return final

# %%
def sum():
    df1 = crawling_ck() #1 경진대회
    df2 = sort_contest() # 2 공모전
    df3 =  final_dreams() # 3 장학금
    df4 = final_allcon() # 4 대외활동
    df5 = sort_job() # 5 취업
    mid = pd.concat([df1, df2, df3, df4, df5]) 
    mid_df = mid.reset_index(drop=True)
    mid_df['title'] = mid_df['title'].str.strip()
    fin_df = mid_df.drop_duplicates(['title'], keep='first')
    fin = fin_df.reset_index(drop = True)
    fin['dday'] = '0'
    print(fin)

    return fin

# %%
sum()
# Out:
# ['한국소프트웨어산업협회', '산업통상자원부', '(주)엔티렉스-디바이스마트']
# {'title': ['2021 SW 챌린지 창업 공모전 (~4/2 마감) ', '제9회 엔지니어링산업설계대전 ', '2021 ICT 융합 프로젝트 공모전 '], 'notice': ['21-02-18', '21-02-01', '21-02-01'], 'deadline': ['21-04-02', '21-03-19', '21-03-31'], 'dday': ['41', '27', '39'], 'sponsor': ['한국소프트웨어산업협회', '산업통상자원부', '(주)엔티렉스-디바이스마트'], 'title2': ['2021 SW 챌린지 창업 공모전 (~4/2 마감) ', '제9회 엔지니어링산업설계대전 ', '2021 ICT 융합 프로젝트 공모전 '], 'link': ['https://thinkyou.co.kr/contest/sector_view.asp?idx=17023&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=0&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16808&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=0&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16631&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=0&serprizeMoney=&seritem=0&searchstr=']}
# C:\Users\yjayh\anaconda3\envs\crawling\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: use driver.switch_to.alert instead
# 40
# 172
# 5
# 1
# 2
# 3
# 4
# 5
# crawling_finish
#      type qualification                           title    notice  deadline  \
# 0    5 취업           대학생        21년 상반기 보안관제 채용연계형 인턴 모집  21-02-15  21-02-21
# 1    5 취업           대학생            미디어로그 Java 개발 경력자 모집  21-02-19  21-03-05
# 2    5 취업           대학생                 콘텐츠 마케팅 경력사원 채용  21-02-18  21-03-01
# 3    5 취업           대학생           CJ프레시웨이 데이터분석 경력사원 모집  21-02-19  21-03-04
# 4    5 취업           대학생               [한국자산평가] 인턴 채용 공고  21-02-20  21-03-01
# ..    ...           ...                             ...       ...       ...
# 167  5 취업           대학생  Field Service Engineer 신입사원 모집  21-02-18  21-02-21
# 168  5 취업           대학생   [교원그룹] e커머스지원팀 경력직 수시채용(웹 개발)  21-02-18  21-03-03
# 169  5 취업           대학생  [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용  21-02-18  21-04-19
# 170  5 취업           대학생            2021년 2월 한미정밀화학 인재채용  21-02-19  21-02-21
# 171  5 취업           대학생                디지털AI전략팀 경력직원 채용  21-02-18  21-03-01
#
#     dday    sponsor                          title2  \
# 0      1        ㈜윈스        21년 상반기 보안관제 채용연계형 인턴 모집
# 1     13     ㈜미디어로그            미디어로그 Java 개발 경력자 모집
# 2      9       ㈜펫츠비                 콘텐츠 마케팅 경력사원 채용
# 3     12   씨제이프레시웨이           CJ프레시웨이 데이터분석 경력사원 모집
# 4      9    한국자산평가㈜               [한국자산평가] 인턴 채용 공고
# ..   ...        ...                             ...
# 167    1    델인터내셔널㈜  Field Service Engineer 신입사원 모집
# 168   11       교원그룹   [교원그룹] e커머스지원팀 경력직 수시채용(웹 개발)
# 169   58     ㈜투비소프트  [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 170    1    한미정밀화학㈜            2021년 2월 한미정밀화학 인재채용
# 171    9  미래에셋자산운용㈜                디지털AI전략팀 경력직원 채용
#
#                                                   link
# 0    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 1    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 2    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 3    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 4    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# ..                                                 ...
# 167  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 168  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 169  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 170  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 171  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
#
# [172 rows x 9 columns]
# 4
# 4
# 1
# 1
# crawling_finish
#    type qualification                                 title    notice  \
# 0  5 취업          대학원생               [전문연구요원] 빅데이터 엔지니어 수시채용  21-02-18
# 1  5 취업          대학원생  2021년도 제1차 전문경력직(연구ㆍ전문ㆍ경력신입) 선발 모집요강  21-02-10
# 2  5 취업          대학원생            [NHN] 2021년 (신입) 전문연구요원 모집  21-01-15
# 3  5 취업          대학원생      머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용  20-12-28
#
#    deadline dday     sponsor                                title2  \
# 0  21-03-10   18         ㈜웹젠               [전문연구요원] 빅데이터 엔지니어 수시채용
# 1  21-02-25    4    한국수력원자력㈜  2021년도 제1차 전문경력직(연구ㆍ전문ㆍ경력신입) 선발 모집요강
# 2  21-04-15   54  엔에이치엔 주식회사            [NHN] 2021년 (신입) 전문연구요원 모집
# 3  21-03-28   36        ㈜씨이랩      머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
#
#                                                 link
# 0  http://www.jobkorea.co.kr/Recruit/GI_Read/3393...
# 1  http://www.jobkorea.co.kr/Recruit/GI_Read/3387...
# 2  http://www.jobkorea.co.kr/Recruit/GI_Read/3366...
# 3  http://www.jobkorea.co.kr/Recruit/GI_Read/3352...
#        type qualification                                       title  \
# 0    1 경진대회        대학(원)생                          스타트업과 함께하는 피버팅 해커톤
# 1    1 경진대회        대학(원)생                             2021 다솜이 드림메이커스
# 2     2 공모전        대학(원)생                         제38회 기상기후 사진·영상 공모전
# 3     2 공모전        대학(원)생                                   슬기로운 과학생활
# 4     2 공모전        대학(원)생                             2021 의료기기 창업공모전
# ..      ...           ...                                         ...
# 165    5 취업          대학원생            머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
# 166    5 취업          대학원생                  [NHN] 2021년 (신입) 전문연구요원 모집
# 167    5 취업           대학생              [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 168    5 취업           대학생                     온라인 미디어서비스 운영및 기술지원자 모집
# 169    5 취업           대학생  [효성ITX] 웹  솔루션/시스템 운영 및 응용프로그램 개발자 경력사원 모집
#
#          notice    deadline dday              sponsor  \
# 0    21. 02. 26  21. 03. 08    0               한국무역협회
# 1    21. 01. 13  21. 12. 31    0     생명보험사회공헌재단, 교보생명
# 2      21-01-28    21-02-25    0                  기상청
# 3      20-09-21    21-10-04    0              국립중앙과학관
# 4    2021-02-23  2021-03-23    0  강원도, 원주시, 한국보건산업진흥원
# ..          ...         ...  ...                  ...
# 165    20-12-28    21-03-28    0                 ㈜씨이랩
# 166    21-01-15    21-04-15    0           엔에이치엔 주식회사
# 167    21-02-18    21-04-19    0               ㈜투비소프트
# 168    21-02-17    21-05-18    0              ㈜씨디네트웍스
# 169    21-02-18    21-05-19    0               효성ITX㈜
#
#                                          title2  \
# 0                            스타트업과 함께하는 피버팅 해커톤
# 1                               2021 다솜이 드림메이커스
# 2                           제38회 기상기후 사진·영상 공모전
# 3                                     슬기로운 과학생활
# 4                               2021 의료기기 창업공모전
# ..                                          ...
# 165            머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
# 166                  [NHN] 2021년 (신입) 전문연구요원 모집
# 167              [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 168                     온라인 미디어서비스 운영및 기술지원자 모집
# 169  [효성ITX] 웹  솔루션/시스템 운영 및 응용프로그램 개발자 경력사원 모집
#
#                                                   link
# 0    https://www.contestkorea.com/sub/view.php?disp...
# 1    https://www.contestkorea.com/sub/view.php?disp...
# 2    https://gongmo.incruit.com/info/gongmolistinfo...
# 3    https://gongmo.incruit.com/info/gongmolistinfo...
# 4    https://www.thinkcontest.com//Contest/ContestD...
# ..                                                 ...
# 165  http://www.jobkorea.co.kr/Recruit/GI_Read/3352...
# 166  http://www.jobkorea.co.kr/Recruit/GI_Read/3366...
# 167  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 168  http://www.jobkorea.co.kr/Recruit/GI_Read/3393...
# 169  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
#
# [170 rows x 9 columns]
#        type qualification                                       title  \
# 0    1 경진대회        대학(원)생                          스타트업과 함께하는 피버팅 해커톤
# 1    1 경진대회        대학(원)생                             2021 다솜이 드림메이커스
# 2     2 공모전        대학(원)생                         제38회 기상기후 사진·영상 공모전
# 3     2 공모전        대학(원)생                                   슬기로운 과학생활
# 4     2 공모전        대학(원)생                             2021 의료기기 창업공모전
# ..      ...           ...                                         ...
# 165    5 취업          대학원생            머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
# 166    5 취업          대학원생                  [NHN] 2021년 (신입) 전문연구요원 모집
# 167    5 취업           대학생              [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 168    5 취업           대학생                     온라인 미디어서비스 운영및 기술지원자 모집
# 169    5 취업           대학생  [효성ITX] 웹  솔루션/시스템 운영 및 응용프로그램 개발자 경력사원 모집
#
#          notice    deadline dday              sponsor  \
# 0    21. 02. 26  21. 03. 08    0               한국무역협회
# 1    21. 01. 13  21. 12. 31    0     생명보험사회공헌재단, 교보생명
# 2      21-01-28    21-02-25    0                  기상청
# 3      20-09-21    21-10-04    0              국립중앙과학관
# 4    2021-02-23  2021-03-23    0  강원도, 원주시, 한국보건산업진흥원
# ..          ...         ...  ...                  ...
# 165    20-12-28    21-03-28    0                 ㈜씨이랩
# 166    21-01-15    21-04-15    0           엔에이치엔 주식회사
# 167    21-02-18    21-04-19    0               ㈜투비소프트
# 168    21-02-17    21-05-18    0              ㈜씨디네트웍스
# 169    21-02-18    21-05-19    0               효성ITX㈜
#
#                                          title2  \
# 0                            스타트업과 함께하는 피버팅 해커톤
# 1                               2021 다솜이 드림메이커스
# 2                           제38회 기상기후 사진·영상 공모전
# 3                                     슬기로운 과학생활
# 4                               2021 의료기기 창업공모전
# ..                                          ...
# 165            머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
# 166                  [NHN] 2021년 (신입) 전문연구요원 모집
# 167              [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 168                     온라인 미디어서비스 운영및 기술지원자 모집
# 169  [효성ITX] 웹  솔루션/시스템 운영 및 응용프로그램 개발자 경력사원 모집
#
#                                                   link
# 0    https://www.contestkorea.com/sub/view.php?disp...
# 1    https://www.contestkorea.com/sub/view.php?disp...
# 2    https://gongmo.incruit.com/info/gongmolistinfo...
# 3    https://gongmo.incruit.com/info/gongmolistinfo...
# 4    https://www.thinkcontest.com//Contest/ContestD...
# ..                                                 ...
# 165  http://www.jobkorea.co.kr/Recruit/GI_Read/3352...
# 166  http://www.jobkorea.co.kr/Recruit/GI_Read/3366...
# 167  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 168  http://www.jobkorea.co.kr/Recruit/GI_Read/3393...
# 169  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
#
# [170 rows x 9 columns]

# %%
def tofb():
    fin = sum()


    postdata = fin.to_dict(orient="index")
    config = {
        "apiKey": "AIzaSyDIo8bt7OrCX6KYaxplvUauQdaehcjUo_0",
        "authDomain": "activity-crawling.firebaseapp.com",
        "databaseURL": "https://activity-crawling-default-rtdb.firebaseio.com",
        "projectId": "activity-crawling",
        "storageBucket": "activity-crawling.appspot.com",
        "messagingSenderId": "608978503357",
        "appId": "1:608978503357:web:374a269b8fa1a64888d9d4"}
    firebase = pyrebase.initialize_app(config)
    db = firebase.database()
    db.remove()
    db.child().update(postdata)

# %%
tofb()
# Out:
# ['한국국제교류재단', '한국산업인력공단, ETS Korea, YBM', '울산광역시 남구 관광과', '서울대학교병원', '고용노동부', 'IBK 기업은행', '(주)LF', '에버랜드', '세종시, 한국토지주택공사', '국토교통부', '열매나눔인터내셔널', '외교부', '국립외교원', '주)메세코리아', '서울시립대학교 도시인문학연구소', '식품의약품안전처', 'blabla', '서초구립반포도서관', '서초구립반포도서관', '한국소프트웨어산업협회']
# {'title': ['2021 KF국민공공외교 프로젝트 공모 ', '월드잡플러스 X 토익스피킹 영어 말하기 대회 ', '울산 관광 유튜브 공모전(Feel the crazy of Ulsan) ', '서울대학교병원 대한외래 멀티-시네마월 영상작품 공모전 ', '2021년 제30회 장애인고용 콘텐츠 공모전 ', 'IBK기업은행 주최 중소기업 학술 컨퍼런스 연구지원 논문 공모전 ', '챔피온 서포터즈 1기 모집 ', '에버랜드 선생님 트렌드 서포터즈 모집 ', '2021 스마트시티 60초 영화제 공모전 ', '2021년도 부동산서비스산업 창업경진대회 ', 'MYI 공식 서포터즈 메리커스 1기 모집 ', 'KOREAZ 명예기자단 모집 ', '국립외교원 제1기 국민외교아카데미 서포터즈 모집 ', '2021 부산국제식품박람회 서포터즈 모집 ', '2021 제 2회 서울시립대학교 도시인문학연구소 영화 평론상 ', '불량식품 근절을 위한 캘리그라피 공모전 ', '전국 대학생 추천 노래자랑 ', '서초구립반포도서관 도서추천 크리에이터 [북포유]-2기 모집 (재능기부자 모집) ', '서초구립반포도서관 대학생 홍보 서포터즈-2기 모집 (재능기부자 모집) ', '2021 SW 챌린지 창업 공모전 (~4/2 마감) '], 'notice': ['21-02-19', '21-02-08', '21-02-22', '21-02-08', '21-02-01', '21-01-15', '21-02-19', '21-02-15', '21-02-22', '21-02-22', '21-02-17', '21-02-10', '21-02-09', '21-02-18', '21-02-18', '21-02-22', '21-02-17', '21-02-14', '21-02-14', '21-02-18'], 'deadline': ['21-03-19', '21-03-07', '21-03-31', '21-04-30', '21-03-14', '21-02-28', '21-02-28', '21-02-28', '21-03-26', '21-05-03', '21-03-01', '21-02-24', '21-02-22', '21-02-21', '21-04-30', '21-04-23', '21-03-14', '21-02-22', '21-02-22', '21-04-02'], 'dday': ['27', '15', '2', '69', '22', '8', '8', '8', '2', '2', '9', '4', '2', '1', '69', '2', '22', '2', '2', '41'], 'sponsor': ['한국국제교류재단', '한국산업인력공단, ETS Korea, YBM', '울산광역시 남구 관광과', '서울대학교병원', '고용노동부', 'IBK 기업은행', '(주)LF', '에버랜드', '세종시, 한국토지주택공사', '국토교통부', '열매나눔인터내셔널', '외교부', '국립외교원', '주)메세코리아', '서울시립대학교 도시인문학연구소', '식품의약품안전처', 'blabla', '서초구립반포도서관', '서초구립반포도서관', '한국소프트웨어산업협회'], 'title2': ['2021 KF국민공공외교 프로젝트 공모 ', '월드잡플러스 X 토익스피킹 영어 말하기 대회 ', '울산 관광 유튜브 공모전(Feel the crazy of Ulsan) ', '서울대학교병원 대한외래 멀티-시네마월 영상작품 공모전 ', '2021년 제30회 장애인고용 콘텐츠 공모전 ', 'IBK기업은행 주최 중소기업 학술 컨퍼런스 연구지원 논문 공모전 ', '챔피온 서포터즈 1기 모집 ', '에버랜드 선생님 트렌드 서포터즈 모집 ', '2021 스마트시티 60초 영화제 공모전 ', '2021년도 부동산서비스산업 창업경진대회 ', 'MYI 공식 서포터즈 메리커스 1기 모집 ', 'KOREAZ 명예기자단 모집 ', '국립외교원 제1기 국민외교아카데미 서포터즈 모집 ', '2021 부산국제식품박람회 서포터즈 모집 ', '2021 제 2회 서울시립대학교 도시인문학연구소 영화 평론상 ', '불량식품 근절을 위한 캘리그라피 공모전 ', '전국 대학생 추천 노래자랑 ', '서초구립반포도서관 도서추천 크리에이터 [북포유]-2기 모집 (재능기부자 모집) ', '서초구립반포도서관 대학생 홍보 서포터즈-2기 모집 (재능기부자 모집) ', '2021 SW 챌린지 창업 공모전 (~4/2 마감) '], 'link': ['https://thinkyou.co.kr/contest/sector_view.asp?idx=17017&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16894&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16939&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16842&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16798&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16618&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=17045&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=17042&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=17040&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=17039&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=17037&page=1&pagesize=30&serstatus=&serdivision=&serfield=&sertarget=&serprizeMoney=&seritem=0&searchstr=', 'https://thinkyou.co.kr/contest/sector_view.asp?idx=17036&page=1&pagesize=30&serstatus=&serdivi ...
# C:\Users\yjayh\anaconda3\envs\crawling\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: use driver.switch_to.alert instead
# 40
# 172
# 5
# 1
# 2
# 3
# 4
# 5
# crawling_finish
#      type qualification                           title    notice  deadline  \
# 0    5 취업           대학생        21년 상반기 보안관제 채용연계형 인턴 모집  21-02-15  21-02-21
# 1    5 취업           대학생            미디어로그 Java 개발 경력자 모집  21-02-19  21-03-05
# 2    5 취업           대학생                 콘텐츠 마케팅 경력사원 채용  21-02-18  21-03-01
# 3    5 취업           대학생           CJ프레시웨이 데이터분석 경력사원 모집  21-02-19  21-03-04
# 4    5 취업           대학생               [한국자산평가] 인턴 채용 공고  21-02-20  21-03-01
# ..    ...           ...                             ...       ...       ...
# 167  5 취업           대학생  Field Service Engineer 신입사원 모집  21-02-18  21-02-21
# 168  5 취업           대학생   [교원그룹] e커머스지원팀 경력직 수시채용(웹 개발)  21-02-18  21-03-03
# 169  5 취업           대학생  [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용  21-02-18  21-04-19
# 170  5 취업           대학생            2021년 2월 한미정밀화학 인재채용  21-02-19  21-02-21
# 171  5 취업           대학생                디지털AI전략팀 경력직원 채용  21-02-18  21-03-01
#
#     dday    sponsor                          title2  \
# 0      1        ㈜윈스        21년 상반기 보안관제 채용연계형 인턴 모집
# 1     13     ㈜미디어로그            미디어로그 Java 개발 경력자 모집
# 2      9       ㈜펫츠비                 콘텐츠 마케팅 경력사원 채용
# 3     12   씨제이프레시웨이           CJ프레시웨이 데이터분석 경력사원 모집
# 4      9    한국자산평가㈜               [한국자산평가] 인턴 채용 공고
# ..   ...        ...                             ...
# 167    1    델인터내셔널㈜  Field Service Engineer 신입사원 모집
# 168   10       교원그룹   [교원그룹] e커머스지원팀 경력직 수시채용(웹 개발)
# 169   58     ㈜투비소프트  [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 170    1    한미정밀화학㈜            2021년 2월 한미정밀화학 인재채용
# 171    9  미래에셋자산운용㈜                디지털AI전략팀 경력직원 채용
#
#                                                   link
# 0    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 1    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 2    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 3    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# 4    http://www.jobkorea.co.kr/Recruit/GI_Read/3395...
# ..                                                 ...
# 167  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 168  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 169  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 170  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 171  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
#
# [172 rows x 9 columns]
# 4
# 4
# 1
# 1
# crawling_finish
#    type qualification                                 title    notice  \
# 0  5 취업          대학원생               [전문연구요원] 빅데이터 엔지니어 수시채용  21-02-18
# 1  5 취업          대학원생  2021년도 제1차 전문경력직(연구ㆍ전문ㆍ경력신입) 선발 모집요강  21-02-10
# 2  5 취업          대학원생            [NHN] 2021년 (신입) 전문연구요원 모집  21-01-15
# 3  5 취업          대학원생      머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용  20-12-28
#
#    deadline dday     sponsor                                title2  \
# 0  21-03-10   18         ㈜웹젠               [전문연구요원] 빅데이터 엔지니어 수시채용
# 1  21-02-25    4    한국수력원자력㈜  2021년도 제1차 전문경력직(연구ㆍ전문ㆍ경력신입) 선발 모집요강
# 2  21-04-15   54  엔에이치엔 주식회사            [NHN] 2021년 (신입) 전문연구요원 모집
# 3  21-03-28   36        ㈜씨이랩      머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
#
#                                                 link
# 0  http://www.jobkorea.co.kr/Recruit/GI_Read/3393...
# 1  http://www.jobkorea.co.kr/Recruit/GI_Read/3387...
# 2  http://www.jobkorea.co.kr/Recruit/GI_Read/3366...
# 3  http://www.jobkorea.co.kr/Recruit/GI_Read/3352...
#        type qualification                                       title  \
# 0    1 경진대회        대학(원)생                          스타트업과 함께하는 피버팅 해커톤
# 1    1 경진대회        대학(원)생                             2021 다솜이 드림메이커스
# 2     2 공모전        대학(원)생                                   슬기로운 과학생활
# 3     2 공모전        대학(원)생                         제38회 기상기후 사진·영상 공모전
# 4     2 공모전        대학(원)생                      2021 부산국제식품박람회 서포터즈 모집
# ..      ...           ...                                         ...
# 184    5 취업          대학원생            머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
# 185    5 취업          대학원생                  [NHN] 2021년 (신입) 전문연구요원 모집
# 186    5 취업           대학생              [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 187    5 취업           대학생                     온라인 미디어서비스 운영및 기술지원자 모집
# 188    5 취업           대학생  [효성ITX] 웹  솔루션/시스템 운영 및 응용프로그램 개발자 경력사원 모집
#
#          notice    deadline dday           sponsor  \
# 0    21. 02. 26  21. 03. 08    0            한국무역협회
# 1    21. 01. 13  21. 12. 31    0  생명보험사회공헌재단, 교보생명
# 2      20-09-21    21-10-04    0           국립중앙과학관
# 3      21-01-28    21-02-25    0               기상청
# 4      21-02-18    21-02-21    0           주)메세코리아
# ..          ...         ...  ...               ...
# 184    20-12-28    21-03-28    0              ㈜씨이랩
# 185    21-01-15    21-04-15    0        엔에이치엔 주식회사
# 186    21-02-18    21-04-19    0            ㈜투비소프트
# 187    21-02-17    21-05-18    0           ㈜씨디네트웍스
# 188    21-02-18    21-05-19    0            효성ITX㈜
#
#                                          title2  \
# 0                            스타트업과 함께하는 피버팅 해커톤
# 1                               2021 다솜이 드림메이커스
# 2                                     슬기로운 과학생활
# 3                           제38회 기상기후 사진·영상 공모전
# 4                       2021 부산국제식품박람회 서포터즈 모집
# ..                                          ...
# 184            머신러닝, 인공지능(AI), 클라우드 연구개발 경력직 채용
# 185                  [NHN] 2021년 (신입) 전문연구요원 모집
# 186              [㈜투비소프트] 연구개발본부 각 부문별 경력개발자 채용
# 187                     온라인 미디어서비스 운영및 기술지원자 모집
# 188  [효성ITX] 웹  솔루션/시스템 운영 및 응용프로그램 개발자 경력사원 모집
#
#                                                   link
# 0    https://www.contestkorea.com/sub/view.php?disp...
# 1    https://www.contestkorea.com/sub/view.php?disp...
# 2    https://gongmo.incruit.com/info/gongmolistinfo...
# 3    https://gongmo.incruit.com/info/gongmolistinfo...
# 4    https://thinkyou.co.kr/contest/sector_view.asp...
# ..                                                 ...
# 184  http://www.jobkorea.co.kr/Recruit/GI_Read/3352...
# 185  http://www.jobkorea.co.kr/Recruit/GI_Read/3366...
# 186  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
# 187  http://www.jobkorea.co.kr/Recruit/GI_Read/3393...
# 188  http://www.jobkorea.co.kr/Recruit/GI_Read/3394...
#
# [189 rows x 9 columns]

# %%
def job():
    now = datetime.now()
    print(now)
    tofb()
    print("end")


schedule.every().day.at("00:00").do(job)

while True:
    schedule.run_pending()
    time.sleep(10)
