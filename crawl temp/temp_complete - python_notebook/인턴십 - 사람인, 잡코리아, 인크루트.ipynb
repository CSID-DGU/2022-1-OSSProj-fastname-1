# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
from bs4 import BeautifulSoup
import re
import urllib.request
from urllib.request import urlopen
import ssl
from dateutil.parser import parse
import json
import requests
from datetime import datetime
context=ssl._create_unverified_context()

# %%
# title, company, link, tag, dday
# 사람인
titles = []
ddays = []
links = []
companies = []
tags = []

for i in range(1, 10):
    cookies = {
        'PCID': '16519199768421417985089',
        '_gcl_au': '1.1.907707392.1651919977',
        '__gads': 'ID=ab02132b4e2dc7db:T=1651919977:S=ALNI_MYSYOO_0DXBZtEYCph0ex5kzWGt2A',
        '_gaexp': 'GAX1.3.TPhZbu4VR1m24zFMhnHzpA.19221.1',
        '_gid': 'GA1.3.763058907.1653127172',
        'PHPSESSID': '8jd9d80f5obtnuttf14o90chpihbujnbl14qccrqr28v048h9j',
        'session_cookie': 'QCHlt.1948432442 | undefined | undefined | undefined | undefined |  | Sun May 22 2022 09:24:25 GMT+0900',
        '__gpi': 'UID=000005335141bee3:T=1651919977:RT=1653179622:S=ALNI_Mb9pUJdE0RJ6o1OxPfs1K_lTC2W9A',
        'mkt_ecommerce_pagepath': '/zf_user/jobs/list/domestic',
        'RSRVID': 'web26|YomJE|YomCu',
        '_ga_GR2XRGQ0FK': 'GS1.1.1653179065.5.1.1653180686.60',
        '_gat': '1',
        'wcs_bt': 's_1d3a45fb0bfe:1653180686',
        '_rc': 'https://www.saramin.co.kr/zf_user/jobs/list/domestic?page=2&loc_mcd=101000&ind_cd=302%2C305%2C306%2C308%2C301&job_type=4&search_optional_item=y&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=domestic&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=3',
        '_ga': 'GA1.3.283320388.1651919977',
        '_gat_UA-12546634-1': '1',
        '_gali': 'job_type_4',
        '_gat_UA-12546634-15': '1',
        '_gat_UA-12546634-22': '1',
    }

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
        'Cache-Control': 'max-age=0',
        'Connection': 'keep-alive',
        # Requests sorts cookies= alphabetically
        # 'Cookie': 'PCID=16519199768421417985089; _gcl_au=1.1.907707392.1651919977; __gads=ID=ab02132b4e2dc7db:T=1651919977:S=ALNI_MYSYOO_0DXBZtEYCph0ex5kzWGt2A; _gaexp=GAX1.3.TPhZbu4VR1m24zFMhnHzpA.19221.1; _gid=GA1.3.763058907.1653127172; PHPSESSID=8jd9d80f5obtnuttf14o90chpihbujnbl14qccrqr28v048h9j; session_cookie=QCHlt.1948432442 | undefined | undefined | undefined | undefined |  | Sun May 22 2022 09:24:25 GMT+0900; __gpi=UID=000005335141bee3:T=1651919977:RT=1653179622:S=ALNI_Mb9pUJdE0RJ6o1OxPfs1K_lTC2W9A; mkt_ecommerce_pagepath=/zf_user/jobs/list/domestic; RSRVID=web26|YomJE|YomCu; _ga_GR2XRGQ0FK=GS1.1.1653179065.5.1.1653180686.60; _gat=1; wcs_bt=s_1d3a45fb0bfe:1653180686; _rc=https://www.saramin.co.kr/zf_user/jobs/list/domestic?page=2&loc_mcd=101000&ind_cd=302%2C305%2C306%2C308%2C301&job_type=4&search_optional_item=y&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=domestic&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=3; _ga=GA1.3.283320388.1651919977; _gat_UA-12546634-1=1; _gali=job_type_4; _gat_UA-12546634-15=1; _gat_UA-12546634-22=1',
        'Referer': 'https://www.saramin.co.kr/zf_user/jobs/list/domestic?page=1&loc_mcd=101000&ind_cd=302%2C305%2C306%2C308%2C301&job_type=4&search_optional_item=y&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=domestic&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=3',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36',
        'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="101", "Google Chrome";v="101"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'page': str(i),
        'loc_mcd': '101000',
        'ind_cd': '302,305,306,308,301',
        'job_type': '4',
        'search_optional_item': 'y',
        'search_done': 'y',
        'panel_count': 'y',
        'isAjaxRequest': '0',
        'page_count': '50',
        'sort': 'RL',
        'type': 'domestic',
        'is_param': '1',
        'isSearchResultEmpty': '1',
        'isSectionHome': '0',
        'searchParamCount': '3',
    }

    response = requests.get('https://www.saramin.co.kr/zf_user/jobs/list/domestic', params=params, cookies=cookies, headers=headers)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    #pagenum = len(soup.select('div.pagination > a'))

    for j in range(0, 50):
        try:
            tag = []
            day = ["상시채용", "오늘마감", "채용시", "내일마감"]
            title = soup.select('a.str_tit')[j*2+1].text
            company = soup.select('a.str_tit')[j*2].text
            dday = soup.select('p.deadlines')[j].text.replace('~', '').lstrip().split('(')[0].replace('/', '. ').rstrip()
            if dday not in day:
                dday = '2022. ' + dday
            else:
                dday = dday            
            link = soup.select('a.str_tit')[j*2]['href']
            link = link.split('=')[-1]
            tag_list = soup.select('.job_meta > span.job_sector')[j]
            tag_num = len(tag_list.select('span'))
            for k in range(tag_num):
                temp = tag_list.select('span')[k].text
                tag.append(temp)
            #자료 저장
            titles.append(title)
            ddays.append(dday)
            links.append('https://www.saramin.co.kr/zf_user/jobs/relay/view?isMypage=no&rec_idx='+str(link)+'&recommend_ids=eJxNT7kVw1AImyY94qbOINl%2Fi%2BB8E1zq6Vah4CR8kusVbxUSFqWGuCCXRFWzwGGVxGzEnBbmOixXIFlXjCjhf5QnSnNYsoJXrFetruQbZjs5dlVm%2FIr8XmUG2yLvIfyAYdhVCe1Z25vC1QdBRxwuiueFw86FSf4CQ%2FlABQ%3D%3D&view_type=list&gz=1&t_ref_content=general&t_ref=area_recruit#seq=0')
            companies.append(company)
            tags.append(tag)
        except:
            break

# %%
intern = []

for i in range(len(titles)):
    li_tmp = {"title": titles[i], "dday": ddays[i], "link": links[i], "company": companies[i], "tag": tags[i]}
    intern.append(li_tmp)

# %%
# 인크루트
# title, company, link, tag, dday
titles = []
ddays = []
links = []
companies = []
tags = []

url = 'https://job.incruit.com/jobdb_list/searchjob.asp?occ1=150&jobty=4&page=1'
req = urllib.request.urlopen(url)
res = req.read()
soup = BeautifulSoup(res,'html.parser')
page_num = len(soup.select('#JobList_Area > div:nth-child(2) > p > a'))
today_month = datetime.today().month
today_day = datetime.today().day

for i in range (1, page_num+1):
    url = 'https://job.incruit.com/jobdb_list/searchjob.asp?occ1=150&jobty=4&page='+str(i)
    req = urllib.request.urlopen(url)
    res = req.read()
    soup = BeautifulSoup(res,'html.parser')
    
    for j in range(0, 60):
        #JobList_Area > div:nth-child(2) > div.cBbslist_contenst > ul:nth-child(1) > li > div.cell_mid > div.cl_top > a
        #JobList_Area > div:nth-child(2) > div.cBbslist_contenst > ul:nth-child(1) > li > div.cell_first > div.cl_top > a
        try:
            title = soup.select('.cl_top > a')[j*2+ 1].text
            link = soup.select('.cl_top > a')[j*2+ 1]['href']  
            company = soup.select('.cl_top > a')[j*2].text
            tag = soup.select('.cl_btm')[j*3 + 1].text.replace('\n', '')
            tag = tag.split(', ')
            dday = soup.select('.cl_btm')[j*3 + 2].text
            if '채용시' in dday or '마감' in dday or '상시' in dday:
                dday = dday.split('(')[0]
            else:
                dday = dday.replace('~', '').split(' ')[0]
                month, day = dday.split('.')
                month = int(month)
                day = int(day)
                if month < today_month:
                    dday = '2023. '+ str(month) +'. '+str(day)
                else:
                    dday = '2022. '+ str(month)+'. '+str(day)

        except:
            break
        titles.append(title)
        ddays.append(dday)
        links.append(link)
        companies.append(company)
        tags.append(tag)

for i in range(len(titles)):
    li_tmp = li_tmp = {"title": titles[i], "dday": ddays[i], "link": links[i], "company": companies[i], "tag": tags[i]}
    intern.append(li_tmp)

# %%
# 잡코리아
# title, company, link, tag, dday
titles = []
ddays = []
links = []
companies = []
tags = []

for i in range(1, 10):
    cookies = {
        'CookieNo': '1610920874',
        'PCID': '16514845459050250101676',
        '__gads': 'ID=c336a58349a51c0e-2281924b88d20005:T=1651484623:RT=1651484623:S=ALNI_Mb-0-OeaFhqwNGo5Uo8CEWEYmUeSg',
        '_ga': 'GA1.3.1481820761.1651484623',
        'mainContents': '0',
        '_fbp': 'fb.2.1651484624285.1762510709',
        'JKStarter': '',
        'ab.storage.deviceId.b9795c74-cdce-4881-a000-eb185c0d072e': '%7B%22g%22%3A%222aecf1db-27d0-3ca0-0816-540a432606d9%22%2C%22c%22%3A1651722470528%2C%22l%22%3A1651722470528%7D',
        'DirectStat': 'ON',
        '_wp_uid': '2-3ff6b48488afe6324baa5c30abaa9ddf-s1650376346.246000|windows_10|chrome-1fd9cv0',
        '_gcl_au': '1.1.947439924.1652351093',
        'G_ENABLED_IDPS': 'google',
        'PositionOfferLayerView': '1',
        'smenu': 'menu%5Fortgi=20220510/121717&menu%5Fpassassay=20220512/192808',
        'StarterRecentMenu': 'Recent0=14&Recent1=16&Recent2=1',
        'ab.storage.sessionId.b9795c74-cdce-4881-a000-eb185c0d072e': '%7B%22g%22%3A%223566b424-e135-e931-e074-28681e6c483e%22%2C%22e%22%3A1652353211045%2C%22c%22%3A1652351197789%2C%22l%22%3A1652351411045%7D',
        '_gac_UA-34423025-1': '1.1652351423.Cj0KCQjw4PKTBhD8ARIsAHChzRIDFn2p44qx4_duBc6xoh_OWVQcTHtJi0CTh4zYYhN6y6MBnKYASuwaAu0_EALw_wcB',
        'GoodJobMenu': 'menu%5Fform=20220513/172503',
        'TR10148105490_t_pa2': '3.460.693.0.336d5ebc5436534e61d16e63ddfca327.d36df91c3a7baa057f8388f1d6c3acda.null.0',
        'recentKeyword': '%5B%22%uC778%uD134%20%uACF5%uACE0%20%uC0AC%uC774%uD2B8%22%2C%22%uC778%uD134%22%5D',
        'DSIF': 'pmax',
        '_gac_UA-75522609-1': '1.1653127095.Cj0KCQjwm6KUBhC3ARIsACIwxBhJ0a9oMIBNcYOy7i2Mf1KBPbHiAI0MLsMbyssvK2ST9dfYN9P9hgMaAu-eEALw_wcB',
        'TR10148105490_t_pa1': '3.460.693.0.336d5ebc5436534e61d16e63ddfca327.c63ff26fb5a8766433a6f32007425820.null.14495127078892140',
        '_gcl_aw': 'GCL.1653383426.Cj0KCQjwhLKUBhDiARIsAMaTLnFA9gi7jg7pDZkHv-uQKjVBIMDXXTDOXGEyiUEun6TltQyuwyvv7c8aAofREALw_wcB',
        '_gac_UA-213826050-3': '1.1653383427.Cj0KCQjwhLKUBhDiARIsAMaTLnFA9gi7jg7pDZkHv-uQKjVBIMDXXTDOXGEyiUEun6TltQyuwyvv7c8aAofREALw_wcB',
        'ASP.NET_SessionId': 'bpiduialf4yuuozcc0shlw0k',
        'jobkorea': 'Site_Oem_Code=C1',
        'GTMVars': '63787639f127dd435acf409c37584ef6',
        'GTMVarsFrom': 'NET:13:51:40',
        'ECHO_SESSION': '8521653540702226',
        '__gpi': 'UID=0000052bedb811d6:T=1651741632:RT=1653540704:S=ALNI_MbKD-W4EtxZ9E0SDjy5ppkfjxGQxg',
        '_gid': 'GA1.3.693575665.1653540704',
        'MainRcntlyData': '%3c%6c%69%3e%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%68%6f%6d%65%22%3e%c3%a4%bf%eb%c1%a4%ba%b8%3c%2f%61%3e%20%26%67%74%3b%20%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%6c%6f%63%61%6c%26%6c%6f%63%61%6c%6f%72%64%65%72%3d%31%22%20%63%6c%61%73%73%3d%22%63%61%74%65%22%3e%c1%f6%bf%aa%ba%b0%3c%2f%61%3e%3c%2f%6c%69%3e%7c%24%24%7c%3c%6c%69%3e%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%68%6f%6d%65%22%3e%c3%a4%bf%eb%c1%a4%ba%b8%3c%2f%61%3e%20%26%67%74%3b%20%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%64%75%74%79%22%20%63%6c%61%73%73%3d%22%63%61%74%65%22%3e%c1%f7%b9%ab%ba%b0%3c%2f%61%3e%3c%2f%6c%69%3e%7c%24%24%7c%3c%6c%69%3e%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%64%75%74%79%22%3e%c1%f7%b9%ab%ba%b0%3c%2f%61%3e%20%26%67%74%3b%20%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%64%75%74%79%26%64%75%74%79%43%74%67%72%3d%31%30%30%31%36%22%20%63%6c%61%73%73%3d%22%63%61%74%65%22%3e%49%54%a1%a4%c0%ce%c5%cd%b3%dd%3c%2f%61%3e%3c%2f%6c%69%3e%7c%24%24%7c',
        'Main_Top_Banner_Seq': '1',
        'TR10148105490_t_uid': '14495555018140948.1653540706054',
        'TR10148105490_t_sst': '14495539400001140.1653540706054',
        'TR10148105490_t_if': '15.0.0.0.null.null.null.0',
        'cto_bundle': 'okytUF9rciUyRkxnckFSVk1xZmVPSUQ4JTJCTjJ3OGhGWCUyRiUyRjhZZnlmcFRLJTJCSEJZQVQ1bURzNUtDQWVIMXlJaDgyS3ZLJTJCZ1VWdlNHd1RtdnZYSVliMHpOTVFoV2h2Q0N1NmZpcldnaSUyQlhNNjBwMnclMkJ5dmtNQlZDZ1dmRm92SHNrRDJSdUZtV3dka2o5QUhXY1o4N0klMkJ3dVptVHdpUnclM0QlM0Q',
        'RSCondition': '[{"CookieIndex":"20220526135436","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000100,1000101,1000102,1000096,1000097,1000104,1000094,1000109,1000110","Employ_Type":"3","Reg_Dt":"2022-05-26T13:54:36.4912113+09:00","IsKeep":true},{"CookieIndex":"20220526135150","Cndt_No":0,"M_Id":"","Employ_Type":"3","Reg_Dt":"2022-05-26T13:51:50.8033792+09:00","IsKeep":true},{"CookieIndex":"20220524181321","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000101,1000102,1000096,1000098,1000104,1000105,1000094,1000109,1000097,1000100","Edu_Level":"5","Employ_Type":"3","Reg_Dt":"2022-05-24T18:13:21.808864+09:00","IsKeep":true},{"CookieIndex":"20220524181246","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000101,1000102,1000096,1000098,1000104,1000105,1000094,1000109,1000100,1000097","Edu_Level":"5","Employ_Type":"3","Reg_Dt":"2022-05-24T18:12:46.2932003+09:00","IsKeep":true},{"CookieIndex":"20220524181213","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000101,1000102,1000096,1000097,1000098,1000104,1000105,1000094,1000109,1000100","Edu_Level":"5","Employ_Type":"3","Reg_Dt":"2022-05-24T18:12:13.0879047+09:00","IsKeep":true}]',
    }

    headers = {
        'Accept': 'text/html, */*; q=0.01',
        'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
        'Connection': 'keep-alive',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        # Requests sorts cookies= alphabetically
        # 'Cookie': 'CookieNo=1610920874; PCID=16514845459050250101676; __gads=ID=c336a58349a51c0e-2281924b88d20005:T=1651484623:RT=1651484623:S=ALNI_Mb-0-OeaFhqwNGo5Uo8CEWEYmUeSg; _ga=GA1.3.1481820761.1651484623; mainContents=0; _fbp=fb.2.1651484624285.1762510709; JKStarter=; ab.storage.deviceId.b9795c74-cdce-4881-a000-eb185c0d072e=%7B%22g%22%3A%222aecf1db-27d0-3ca0-0816-540a432606d9%22%2C%22c%22%3A1651722470528%2C%22l%22%3A1651722470528%7D; DirectStat=ON; _wp_uid=2-3ff6b48488afe6324baa5c30abaa9ddf-s1650376346.246000|windows_10|chrome-1fd9cv0; _gcl_au=1.1.947439924.1652351093; G_ENABLED_IDPS=google; PositionOfferLayerView=1; smenu=menu%5Fortgi=20220510/121717&menu%5Fpassassay=20220512/192808; StarterRecentMenu=Recent0=14&Recent1=16&Recent2=1; ab.storage.sessionId.b9795c74-cdce-4881-a000-eb185c0d072e=%7B%22g%22%3A%223566b424-e135-e931-e074-28681e6c483e%22%2C%22e%22%3A1652353211045%2C%22c%22%3A1652351197789%2C%22l%22%3A1652351411045%7D; _gac_UA-34423025-1=1.1652351423.Cj0KCQjw4PKTBhD8ARIsAHChzRIDFn2p44qx4_duBc6xoh_OWVQcTHtJi0CTh4zYYhN6y6MBnKYASuwaAu0_EALw_wcB; GoodJobMenu=menu%5Fform=20220513/172503; TR10148105490_t_pa2=3.460.693.0.336d5ebc5436534e61d16e63ddfca327.d36df91c3a7baa057f8388f1d6c3acda.null.0; recentKeyword=%5B%22%uC778%uD134%20%uACF5%uACE0%20%uC0AC%uC774%uD2B8%22%2C%22%uC778%uD134%22%5D; DSIF=pmax; _gac_UA-75522609-1=1.1653127095.Cj0KCQjwm6KUBhC3ARIsACIwxBhJ0a9oMIBNcYOy7i2Mf1KBPbHiAI0MLsMbyssvK2ST9dfYN9P9hgMaAu-eEALw_wcB; TR10148105490_t_pa1=3.460.693.0.336d5ebc5436534e61d16e63ddfca327.c63ff26fb5a8766433a6f32007425820.null.14495127078892140; _gcl_aw=GCL.1653383426.Cj0KCQjwhLKUBhDiARIsAMaTLnFA9gi7jg7pDZkHv-uQKjVBIMDXXTDOXGEyiUEun6TltQyuwyvv7c8aAofREALw_wcB; _gac_UA-213826050-3=1.1653383427.Cj0KCQjwhLKUBhDiARIsAMaTLnFA9gi7jg7pDZkHv-uQKjVBIMDXXTDOXGEyiUEun6TltQyuwyvv7c8aAofREALw_wcB; ASP.NET_SessionId=bpiduialf4yuuozcc0shlw0k; jobkorea=Site_Oem_Code=C1; GTMVars=63787639f127dd435acf409c37584ef6; GTMVarsFrom=NET:13:51:40; ECHO_SESSION=8521653540702226; __gpi=UID=0000052bedb811d6:T=1651741632:RT=1653540704:S=ALNI_MbKD-W4EtxZ9E0SDjy5ppkfjxGQxg; _gid=GA1.3.693575665.1653540704; MainRcntlyData=%3c%6c%69%3e%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%68%6f%6d%65%22%3e%c3%a4%bf%eb%c1%a4%ba%b8%3c%2f%61%3e%20%26%67%74%3b%20%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%6c%6f%63%61%6c%26%6c%6f%63%61%6c%6f%72%64%65%72%3d%31%22%20%63%6c%61%73%73%3d%22%63%61%74%65%22%3e%c1%f6%bf%aa%ba%b0%3c%2f%61%3e%3c%2f%6c%69%3e%7c%24%24%7c%3c%6c%69%3e%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%68%6f%6d%65%22%3e%c3%a4%bf%eb%c1%a4%ba%b8%3c%2f%61%3e%20%26%67%74%3b%20%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%64%75%74%79%22%20%63%6c%61%73%73%3d%22%63%61%74%65%22%3e%c1%f7%b9%ab%ba%b0%3c%2f%61%3e%3c%2f%6c%69%3e%7c%24%24%7c%3c%6c%69%3e%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%64%75%74%79%22%3e%c1%f7%b9%ab%ba%b0%3c%2f%61%3e%20%26%67%74%3b%20%3c%61%20%68%72%65%66%3d%22%2f%72%65%63%72%75%69%74%2f%6a%6f%62%6c%69%73%74%3f%6d%65%6e%75%63%6f%64%65%3d%64%75%74%79%26%64%75%74%79%43%74%67%72%3d%31%30%30%31%36%22%20%63%6c%61%73%73%3d%22%63%61%74%65%22%3e%49%54%a1%a4%c0%ce%c5%cd%b3%dd%3c%2f%61%3e%3c%2f%6c%69%3e%7c%24%24%7c; Main_Top_Banner_Seq=1; TR10148105490_t_uid=14495555018140948.1653540706054; TR10148105490_t_sst=14495539400001140.1653540706054; TR10148105490_t_if=15.0.0.0.null.null.null.0; cto_bundle=okytUF9rciUyRkxnckFSVk1xZmVPSUQ4JTJCTjJ3OGhGWCUyRiUyRjhZZnlmcFRLJTJCSEJZQVQ1bURzNUtDQWVIMXlJaDgyS3ZLJTJCZ1VWdlNHd1RtdnZYSVliMHpOTVFoV2h2Q0N1NmZpcldnaSUyQlhNNjBwMnclMkJ5dmtNQlZDZ1dmRm92SHNrRDJSdUZtV3dka2o5QUhXY1o4N0klMkJ3dVptVHdpUnclM0QlM0Q; RSCondition=[{"CookieIndex":"20220526135436","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000100,1000101,1000102,1000096,1000097,1000104,1000094,1000109,1000110","Employ_Type":"3","Reg_Dt":"2022-05-26T13:54:36.4912113+09:00","IsKeep":true},{"CookieIndex":"20220526135150","Cndt_No":0,"M_Id":"","Employ_Type":"3","Reg_Dt":"2022-05-26T13:51:50.8033792+09:00","IsKeep":true},{"CookieIndex":"20220524181321","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000101,1000102,1000096,1000098,1000104,1000105,1000094,1000109,1000097,1000100","Edu_Level":"5","Employ_Type":"3","Reg_Dt":"2022-05-24T18:13:21.808864+09:00","IsKeep":true},{"CookieIndex":"20220524181246","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000101,1000102,1000096,1000098,1000104,1000105,1000094,1000109,1000100,1000097","Edu_Level":"5","Employ_Type":"3","Reg_Dt":"2022-05-24T18:12:46.2932003+09:00","IsKeep":true},{"CookieIndex":"20220524181213","Cndt_No":0,"M_Id":"","Jobtype_Code":"1000101,1000102,1000096,1000097,1000098,1000104,1000105,1000094,1000109,1000100","Edu_Level":"5","Employ_Type":"3","Reg_Dt":"2022-05-24T18:12:13.0879047+09:00","IsKeep":true}]',
        'Origin': 'https://www.jobkorea.co.kr',
        'Referer': 'https://www.jobkorea.co.kr/recruit/joblist?menucode=local&localorder=1',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36',
        'X-Requested-With': 'XMLHttpRequest',
        'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="101", "Google Chrome";v="101"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    data = {
        'page': str(i),
        'condition[jobtype]': '3',
        'condition[duty]': '1000100,1000101,1000102,1000096,1000097,1000104,1000094,1000109,1000110',
        'condition[menucode]': '',
        'direct': '0',
        'order': '20',
        'pagesize': '40',
        'tabindex': '0',
        'fulltime': '0',
        'confirm': '0',
    }

    response = requests.post('https://www.jobkorea.co.kr/Recruit/Home/_GI_List/', cookies=cookies, headers=headers, data=data)

    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title_num = len(soup.select('.titBx')) # 40

    for j in range(0, 40):
        try:
            box = soup.select('.titBx')[j] # 여기만 숫자 변경
            title = box.select('a')[0].text
            company = soup.select('td.tplCo > a')[j].text
            link = 'https://www.jobkorea.co.kr/'+box.select('a')[0]['href']
            tag = box.select('.dsc')[0].text
            tag = tag.split(', ')
            dday = soup.select('td.odd > span.date.dotum')[j].text
            if '상시채용' in dday or '오늘마감' in dday or '내일마감' in dday:
                dday = dday
            else:
                dday = dday.replace('~', '').split('(')[0]
                month, day = dday.split('/')
                dday = '2022. '+month+'. '+day
            titles.append(title)
            ddays.append(dday)
            links.append(link)
            companies.append(company)
            tags.append(tag)
        except:
            break

for i in range(len(titles)):
    li_tmp = li_tmp = {"title": titles[i], "dday": ddays[i], "link": links[i], "company": companies[i], "tag": tags[i]}
    intern.append(li_tmp)

# %%
df = pd.DataFrame(intern)
df = df.drop_duplicates(['title'], keep='first')
df = df.sort_values(by=['dday'])
df = df.reset_index(drop=True)

# %%
titles = []
ddays = []
links = []
companies= []
tags = []
intern = []
new_tags = []
check_app = ['iOS', '앱', '게임', '소프트웨어', '응용', '어플리케이션', '아이폰', '안드로이드']
check_AI = ['AI', 'IoT', '러닝', '인공지능']
check_web = ['웹', '엔드', 'HTML', 'web']
check_data = ['데이터', 'DB','Data']
check_server = ['서버', '블록체인', '보안']
check_system = ['Unix', 'Linux', '임베디드','시스템']

for i in range(len(df)):
    ttag = []
    title = df.iloc[i][0]
    dday = df.iloc[i][1]
    link = df.iloc[i][2]
    company = df.iloc[i][3]
    tag= df.iloc[i][4]
    for k in tag:
        if any(word in k for word in check_app):        
            ttag.append('응용')
        if any(word in k for word in check_AI):         
            ttag.append('인공지능')
        if any(word in k for word in check_web):       
            ttag.append('웹')
        if any(word in k for word in check_data):      
            ttag.append('데이터')
        if any(word in k for word in check_server):
            ttag.append('서버')
        if any(word in k for word in check_system):
            ttag.append('시스템')
    if len(ttag) == 0:
        ttag.append('기타')
    result = set(ttag)
    ttag = list(result)
    titles.append(title)
    ddays.append(dday)
    links.append(link)
    companies.append(company)
    tags.append(tag)
    new_tags.append(ttag)

for i in range(len(titles)):
    li_tmp = {"title": titles[i], "dday": ddays[i], "link": links[i], "company": companies[i], "tag": tags[i], "bigtag":new_tags[i]}
    intern.append(li_tmp)

# %%
with open('../json 결과/인턴십.json', 'w', encoding='UTF-8') as file:
     file.write(json.dumps(intern, ensure_ascii=False, indent="\t"))

# %%
df = pd.DataFrame(intern)
df2 = df['tag'].reset_index(drop=True)
tag_index = []
for i in df2:
    for t in i:
        tag_index.append(t)

df3 = pd.DataFrame(tag_index)
df4 = df3[0].value_counts()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#pd.reset_option()
print(df4)
# Out:
# Java                    103
# 소프트웨어개발                  90
# 솔루션                      69
# 웹프로그래머                   60
# Python                   56
# 응용프로그래머                  51
# ERP·시스템분석·설계             50
# 빅데이터                     47
# 안드로이드                    43
# 유지보수                     40
# SQL                      35
# 웹개발                      35
# MySQL                    35
# 빅데이터·AI(인공지능)            34
# 웹디자인                     34
# C#                       33
# 아이폰                      30
# 소프트웨어                    30
# 정보보안                     30
# 컨텐츠·사이트운영                29
# HTML                     29
# 모바일앱개발                   29
# SI                       29
# 마케팅기획                    28
# 마케팅                      28
# 웹기획·웹마케팅·PM              27
# C++                      25
# 일반사무·사무지원                25
# jsp                      24
# UI·UX디자인                 24
# Linux                    24
# 자바스크립트                   24
# 전산·IT기술지원                23
# 앱개발                      23
# 인공지능(AI)                 22
# CSS                      22
# BigData                  21
# 데이터분석                    21
# API                      21
# 하드웨어                     20
# 백엔드/서버개발                 20
# 광고·CG·시각디자인              20
# 기획                       20
# 포토샵                      19
# 프론트엔드                    19
# 웹기획                      19
# 네트워크·서버·보안               18
# 웹퍼블리셔                    17
# 기술영업                     17
# 게임개발                     17
# 조사·분석·통계                 17
# php                      17
# MS-SQL                   16
# 보안컨설팅                    16
# 기술지원                     16
# 바이럴마케팅                   15
# 딥러닝                      15
# 머신러닝(ML)                 15
# Oracle                   15
# 모바일게임                    15
# 총무                       15
# 소프트웨어·하드웨어               15
# 데이터베이스                   15
# 모바일App                   15
# 사무보조                     15
# 통신·모바일                   15
# HTML5                    14
# 시스템운영                    14
# UI·UX                    14
# 서비스기획                    14
# .NET                     14
# 경영·기획·전략                 14
# 일러스트레이터                  13
# Windows                  13
# 영업관리                     13
# BI                       13
# 데이터베이스·DBA               13
# Android                  13
# 온라인마케팅                   13
# 서버관리자                    12
# 서버구축                     12
# C                        12
# 게임디자인                    12
# 영업지원                     12
# 마케팅전략                    12
# 홍보·PR·전시·컨벤션             11
# AI(인공지능)                 11
# 머신러닝                     11
# SNS마케팅                   11
# UI/UX디자인                 11
# HTML코딩                   11
# 웹UI                      11
# 스토리보드                    11
# 그래픽디자인                   11
# 네트워크엔지니어                 11
# 시각디자인                    11
# SM                       11
# 모바일                      10
# 시스템프로그래머                 10
# 멀티미디어(동영상·음향)            10
# 앱기획                      10
# 모바일UI                    10
# IT컨설팅                    10
# 웹표준                      10
# 게임마케팅                    10
# 게임기획                     10
# Application              10
# 사업기획                     10
# QA                       10
# SNS                      10
# 데이터분석가                    9
# UI설계                      9
# 증강현실                      9
# 모바일앱게임                    9
# 경영지원                      9
# React                     9
# 방화벽                       9
# 웹마케팅                      9
# DBA                       9
# 컨텐츠관리                     9
# 컨텐츠개발                     9
# tensorflow                9
# 보안기술                      9
# 컨텐츠기획                     9
# 고객관리                      9
# 모바일기획                     9
# 데이터마이닝                    9
# UI/UX                     9
# 영상편집                      9
# R                         8
# 사무직                       8
# CRM                       8
# Kotlin                    8
# S/W                       8
# 컨설턴트                      8
# 경영기획                      8
# 네트워크                      8
# 세무·회계                     8
# 문서작성                      8
# 테스터                       8
# 광고디자인                     8
# 보안관리                      8
# 가상현실                      8
# 유통·상품기획·MD                8
# AJAX                      8
# 쇼핑몰                       8
# GUI                       7
# 게임소프트웨어                   7
# 게임(Game)                  7
# Ajax                      7
# 사이트관리                     7
# 웹에이전시                     7
# 비품관리                      7
# CSS3                      7
# 사무행정                      7
# 웹접근성                      7
# 웹서비스기획                    7
# 컨텐츠                       7
# 앱디자인                      7
# 스마트폰                      7
# 해킹                        7
# 블록체인                      7
# 콘텐츠기획                     7
# 클라우드                      7
# 네트워크관리                    7
# iOS                       7
# 캐주얼게임                     7
# 인사                        7
# 광고·광고기획(AE)               7
# 콘텐츠관리                     7
# 영업관리·영업지원                 6
# 사물인터넷(IoT)                6
# 컴퓨터                       6
# 채용담당자                     6
# 교육기획                      6
# 펌웨어                       6
# 영업기획                      6
# IT·문화·직업강사                6
# HRM                       6
# 광고기획                      6
# 카페·블로그관리                  6
# 방송제작·연출·촬영·기자             6
# 데이터시각화                    6
# 모바일디자인                    6
# 웹사이트운영                    6
# 게시판관리                     6
# PM                        6
# ERP                       6
# 리서치                       6
# 데이터엔지니어                   6
# QA/테스터                    6
# 해외영업                      6
# 의료기기                      6
# Flutter                   6
# 게임운영관리                    6
# 회계                        5
# 오픈마켓                      5
# 연구원·연구개발                  5
# ASP.NET                   5
# 기획조사                      5
# 전자상거래                     5
# 네트워크보안                    5
# 일러스트                      5
# 웹마스터                      5
# 상품기획                      5
# 디지털디자인                    5
# 블로그마케팅                    5
# 게임운영                      5
# 인플루언서마케팅                  5
# 제품·산업디자인                  5
# asp                       5
# 디지털마케팅                    5
# 거래처관리                     5
# 사업제휴                      5
# 검증                        5
# 컨텐츠에디터                    5
# 퍼블리셔                      5
# 온라인MD                     5
# PM(프로젝트매니저)               5
# 고객상담                      5
# 보안소프트웨어                   5
# 소셜미디어                     5
# 고객응대                      5
# 물류                        5
# 클라이언트개발                   5
# 게임방송                      5
# Node.js                   5
# 영업직                       5
# 보드게임                      5
# 경리                        5
# 문서관리                      5
# 바이오                       4
# VB.NET                    4
# 전략                        4
# 신규사업·BD                   4
# 캐릭터·애니메이션                 4
# 전산전공                      4
# 재무·자금·IR                  4
# 애니메이션                     4
# 전화응대                      4
# 시장조사                      4
# 데이터라벨링                    4
# 모바일마케팅                    4
# 보안ASP                     4
# 건설현장                      4
# 일반영업                      4
# 기자                        4
# DevOps                    4
# MD                        4
# 시장분석                      4
# 프로모션                      4
# 자재관리                      4
# 임원·경영분석·컨설팅               4
# 소셜커머스                     4
# 생산관리                      4
# 재무                        4
# 일반·법인영업                   4
# 시스템엔지니어                   4
# 고객지원                      4
# 솔루션기술영업                   4
# 소셜마케팅                     4
# 웹광고기획                     4
# 전문번역·통역                   4
# 광고영업                      4
# 출판·편집디자인                  4
# 사무관리                      4
# 교수설계                      4
# 교육진행                      4
# SE(시스템엔지니어)               4
# 광고마케팅                     4
# Javascript                4
# Excel                     4
# 캐릭터                       4
# 통/번역                      4
# 웹프로모션                     4
# 사내행사                      4
# 포워딩                       4
# 시설관리                      4
# AMD                       4
# 품질관리                      4
# 인사·채용·인재개발(HRM·HRD)       4
# 건축·공간·CAD·CAM디자인          4
# 전략기획                      4
# 교육프로그램                    4
# 알고리즘                      3
# SCM                       3
# 콘텐츠에디터                    3
# 설문조사                      3
# 교육·교재개발                   3
# Figma                     3
# 반응형웹                      3
# HRD                       3
# APM                       3
# 챗봇(Chatbot)               3
# 인사기획                      3
# Git                       3
# 제약                        3
# 브랜드마케팅                    3
# 해외마케팅                     3
# 경영컨설팅                     3
# B2C                       3
# 시스템분석                     3
# 디자인                       3
# 수출입무역                     3
# 신상품개발                     3
# Unix                      3
# 자재구매기획                    3
# 자재구매                      3
# 외자구매                      3
# 업무제휴                      3
# 운송·물류                     3
# 인바운드TM                    3
# 브랜딩                       3
# CS                        3
# 영상디자인                     3
# VisualBasic               3
# 제안·컨설팅                    3
# AWS                       3
# 패션·잡화디자인                  3
# 온라인광고                     3
# 인터넷게임                     3
# JSP                       3
# PR                        3
# xml                       3
# 자산관리                      3
# 프리미어                      3
# SNS운영                     3
# 법인영업                      3
# 관리회계                      3
# 교육                        3
# NLP(자연어처리)                3
# 소셜네트워크서비스(SNS)            3
# 산업디자인                     3
# JavaScript                3
# 영업                        3
# 결산                        3
# 스토리텔링                     3
# NODE.JS                   3
# PD/AD/FD                  3
# 물류관리                      3
# 전표입력                      3
# 시스템영업                     3
# 홍보                        3
# 전시디자인                     3
# SWIFT                     3
# 자료입력                      3
# 더존                        3
# 인재개발                      3
# 콘텐츠디자인                    3
# 일본어                       3
# Vue                       3
# 개발자                       3
# 인터넷방송                     3
# DataMining                3
# 자연어처리(NLP)                3
# 시스템설계                     3
# 콘텐츠마케팅                    3
# C언어                       3
# 트렌드분석                     3
# WAS                       3
# Node                      3
# 채용·면접                     2
# CG                        2
# 솔루션영업                     2
# 기획MD                      2
# 법무                        2
# 출판기획                      2
# 패션잡화                      2
# 통계·로그분석                   2
# 요구분석                      2
# 작가                        2
# 그림작가                      2
# 서무                        2
# 애니메이터                     2
# 하둡(Hadoop)                2
# 설치·수리·정비·A/S              2
# 프로게이머                     2
# 웹표준·웹접근성                  2
# express                   2
# HTML·퍼블리싱·UI개발            2
# 교육상담                      2
# 상품입출고                     2
# 은행                        2
# 편집디자인(IBM)                2
# FPGA                      2
# 프론트개발                     2
# 관리                        2
# KMS                       2
# 변화관리                      2
# 섬유·화학                     2
# 인사통합                      2
# GIS                       2
# 프로그램상담                    2
# AE(광고기획자)                 2
# 전자·반도체                    2
# 매출관리                      2
# 보안관제                      2
# 전산회계                      2
# AS                        2
# 정보처리기사                    2
# 연구소                       2
# 인터넷교육                     2
# 건축·인테리어·설계                2
# 부가세신고                     2
# 로고디자인                     2
# 포토그래퍼                     2
# 브랜드기획                     2
# 홍보기획                      2
# 전산총무                      2
# PowerPoint                2
# OA                        2
# A·S                       2
# H/W                       2
# CX매니저                     2
# IT영업                      2
# 패키지디자인                    2
# 연구원                       2
# 게임시나리오                    2
# 무역사무                      2
# SPRING                    2
# 생산·조립·가공·포장·검품            2
# 영어                        2
# 공간디자인                     2
# 회원분석                      2
# 상품분석                      2
# 경영관리                      2
# 자동차보험                     2
# OpenStack                 2
# 교재컨텐츠개발                   2
# spring boot               2
# 코인                        2
# MLOps                     2
# aiops                     2
# 백엔드                       2
# 가상화폐                      2
# 프론트엔드 개발                  2
# 프로덕션                      2
# DataWarehouse             2
# 무선통신                      2
# IT학원                      2
# 중국어                       2
# 실내디자인                     2
# 무역                        2
# VisualC++                 2
# ISMS                      2
# IOS                       2
# 배너디자인                     2
# 세무                        2
# 섬유                        2
# 의류                        2
# 패션                        2
# 글로벌마케팅                    2
# 모델링                       2
# ISP                       2
# 인사행정                      2
# 손해사정                      2
# 토목                        2
# 측량                        2
# 정보처리                      2
# 브랜드디자인                    2
# 비서·안내                     2
# Kubernetes                2
# 금융사무·심사·추심                2
# 교육행정                      2
# 인플루언서                     2
# DW                        2
# 교육운영                      2
# jQuery                    2
# 광고대행                      2
# 전자                        2
# 홍보대행                      2
# 콜센터                       2
# Unity                     2
# GM·CS                     2
# 커뮤니티                      2
# 콘솔게임                      2
# ICT컨설팅                    2
# 2D디자인                     2
# 리테일MD                     2
# 아트디렉터                     2
# 영상제작                      2
# 해상운송                      2
# 퍼블리싱                      2
# 구매·자재                     2
# 바이어개발                     2
# 스토리지                      2
# 바이어상담                     2
# Spark                     2
# 학원운영                      2
# ERP운용                     2
# 재무회계                      2
# 키워드광고                     2
# Apache                    2
# 네트웍구축                     2
# 사회조사                      2
# DBMS                      2
# AR                        2
# 병역특례                      2
# 웹컨설팅                      2
# MMORPG                    2
# 총무·법무·특허                  2
# 게임CS                      2
# 채용공고관리                    2
# MariaDB                   2
# PhotoShop                 2
# 취약점진단                     2
# Spring                    2
# 모의해킹                      2
# Back-end                  2
# Servlet                   2
# 리액트                       2
# SI개발                      2
# 비서                        2
# 매장관리                      1
# 웹게임                       1
# 원화디자인                     1
# Cisco                     1
# 유아원교사                     1
# 유아원                       1
# 어린이집                      1
# 마켓팅                       1
# MFC                       1
# 유비쿼터스                     1
# 도시계획                      1
# 건설                        1
# UX디자인                     1
# UI디자인                     1
# 타당성분석                     1
# 한국어                       1
# 기계·금속기능                   1
# 유닛테스트                     1
# POS                       1
# 프로토타이핑                    1
# 소비재                       1
# REST                      1
# 4대보험                      1
# MVP패턴                     1
# 납기관리                      1
# 기업영업                      1
# 이카운트                      1
# 트러블슈팅                     1
# 유치원교사                     1
# 플래쉬                       1
# ESM                       1
# Java게임                    1
# 기계·금속·재료                  1
# 관리자                       1
# 판매직                       1
# 캐셔                        1
# 정보통신                      1
# 자동차                       1
# SPA                       1
# GIT                       1
# 생산                        1
# 공정관리                      1
# 공정                        1
# 세일즈                       1
# 영업보조                      1
# 인사담당                      1
# 인공지능 서비스 기획자              1
# 서버                        1
# 문화기획                      1
# e스포츠                      1
# 교육훈련                      1
# 전산                        1
# 이커머스 개발                   1
# 디자인기타                     1
# 콜센터운영                     1
# 스튜디오                      1
# 리액트 네이티브                  1
# 운전·운항                     1
# 법인고객영업                    1
# 대인보상기획                    1
# 인프라AA                     1
# 손해보험                      1
# 송무                        1
# 인허가업무                     1
# 개인고객영업                    1
# 보험설계                      1
# JVM                       1
# 보험영업                      1
# 보험                        1
# 아웃바운드TM                   1
# 보험회사                      1
# 제품홍보                      1
# 튜닝                        1
# SCRUM                     1
# IFRS17                    1
# 모바일 앱 개발 iOS/Android      1
# 대인보상                      1
# 리눅스                       1
# 원화                        1
# DB2                       1
# PowerBuilder              1
# 건강보험                      1
# 대물보상                      1
# 리스크관리                     1
# FrameWork                 1
# 손익관리                      1
# 일반보험                      1
# Agile                     1
# Akka                      1
# Architect                 1
# FRM                       1
# 보험심사·청구                   1
# 보상                        1
# 보험심사                      1
# Nginx                     1
# SAS                       1
# 애널리스트                     1
# 유튜브                       1
# 애프터이펙트                    1
# 안내데스크                     1
# 내방객응대                     1
# 자료조사                      1
# 보험계리사                     1
# A/S기사                     1
# 기계수리                      1
# 영업마케팅                     1
# XD                        1
# 관광가이드                     1
# 관광통역안내사                   1
# SEO                       1
# 악성코드                      1
# 작가·문화·예술·창작               1
# 검색광고                      1
# 광고PD                      1
# 투자·분석·증권·외환               1
# ASP                       1
# 고객상담·관리·수퍼바이저             1
# CFO                       1
# IR/공시                     1
# BI디자인                     1
# VMware                    1
# CW(카피라이터)                 1
# 프리뷰어                      1
# Xamarin                   1
# 앱 개발자                     1
# 언더라이팅                     1
# Nodejs                    1
# 임베디드 개발                   1
# 식품가공·농림어업                 1
# OCP                       1
# PL                        1
# springboot                1
# SpringFramework           1
# 방송기획                      1
# 방송제작                      1
# PD·연출                     1
# 이벤트프로모션                   1
# Sybase                    1
# 스마트폰게임                    1
# 카페운영                      1
# GM                        1
# 인바운드                      1
# ReactNative               1
# 이미지프로세싱                   1
# 전자정부프레임워크                 1
# 데이터라벨러                    1
# 백엔드 개발                    1
# 여행·레저                     1
# 전기·소방·설비                  1
# 인문사회연구·종교                 1
# 법률·법무·회계                  1
# 토목·조경·도시·측량               1
# 진행·연예·모델·매니저              1
# 간호·간병                     1
# 이벤트·나레이터·결혼               1
# 회계결산                      1
# 광학·의료장비                   1
# 전기·전자·통신기능                1
# Embedded                  1
# 세무기장                      1
# 세무신고                      1
# 세무회계                      1
# 인터페이스                     1
# angularjs                 1
# 골프장                       1
# 생명공학                      1
# Zeplin                    1
# 제조                        1
# 조립                        1
# webgl                     1
# Django                    1
# Flask                     1
# 의약                        1
# 스포츠                       1
# 자동제어                      1
# 전기                        1
# 전기제어                      1
# 제어                        1
# VisualC                   1
# 컨설팅                       1
# Sketch                    1
# react.js                  1
# Front-end                 1
# 자금관리                      1
# 법인결산                      1
# 의약품                       1
# IT학원강사                    1
# 컴퓨터학원강사                   1
# 학원강사                      1
# 웹프로덕션                     1
# 신사업기획                     1
# 사업개발                      1
# 무인항공기/드론                  1
# BTL                       1
# ATL                       1
# OLAP                      1
# HDML                      1
# 3D모델편집                    1
# 현수막디자인                    1
# VTK                       1
# 관공서 유지보수                  1
# 핀테크                       1
# 관공서                       1
# 세종시                       1
# PC유지보수                    1
# PC                        1
# 관공서 서버                    1
# 관공서 PC 유지보수               1
# Tomcat                    1
# 전산사무기기 유지보수               1
# ㈜아이넷                      1
# 프린터 복사기                   1
# 설치                        1
# 수리                        1
# PHP                       1
# IaaS                      1
# PaaS                      1
# 성과관리                      1
# 데이터 파이프라인                 1
# 풀스택                       1
# RESTful API               1
# 오픈소스                      1
# 자동화                       1
# Ansible                   1
# K8s                       1
# dataops                   1
# 미들웨어                      1
# GM(게임운영)                  1
# WinForm                   1
# AMQP                      1
# RxJava                    1
# RxSwift                   1
# 잡매니저                      1
# 광고제작                      1
# 디자이너                      1
# 레벨                        1
# SW                        1
# 스포츠에이전트                   1
# 생활체육                      1
# 축구                        1
# 백엔드개발                     1
# 솔루션개발                     1
# IT솔루션                     1
# 건강                        1
# 레벨 기획                     1
# 약국                        1
# 영양                        1
# jquery                    1
# 문서수발                      1
# 복리후생관리                    1
# 노사관리                      1
# 스포츠강사                     1
# DM광고                      1
# 제품디자인                     1
# 잡화디자인                     1
# 섬유디자인                     1
# 공업디자인                     1
# VMD                       1
# 프랜차이즈                     1
# 슈퍼바이저                     1
# 오더관리                      1
# 무역사                       1
# 바이어관리                     1
# 무역일반                      1
# 세재개발                      1
# 크리에이티브디렉터                 1
# 아키텍쳐                      1
# 스팀게임                      1
# 프론트 엔드                    1
# kubernetes                1
# 인프라                       1
# app개발                     1
# 대기환경                      1
# 기술연구                      1
# 알고리즘개발                    1
# 일본어가능자                    1
# 모바일개발                     1
# 모바일플랫폼                    1
# 모바일UI개발                   1
# 쇼핑몰관리                     1
# 거래선개발관리                   1
# 온라인프로모션                   1
# 온라인영업                     1
# 수강생관리                     1
# 회원관리                      1
# 항공운송                      1
# R&D                       1
# 홈페이지관리                    1
# 프로그램 설치                   1
# 프로그램 교육                   1
# 컴퓨터공학                     1
# 전산학과                      1
# 전산관련학과                    1
# 정산관리                      1
# 전산편집                      1
# 전산입력                      1
# 화물차(카고)                   1
# 1톤                        1
# 택배기사                      1
# 배송기사                      1
# 물류기사                      1
# 브랜드관리                     1
# RDBMS                     1
# 온라인판매                     1
# 드림위버                      1
# CAD                       1
# DB 제작                     1
# 학습매니저                     1
# 교육컨텐츠기획                   1
# 어학원                       1
# 과외                        1
# 고등학교                      1
# 데이터분류                     1
# 제안서                       1
# Swift                     1
# 사업관리                      1
# 전자출판                      1
# Azure                     1
# Docker                    1
# 면접/인터뷰                    1
# 온보딩                       1
# 스포츠마케팅                    1
# 문구디자인                     1
# 브랜드확장                     1
# 브랜드런칭                     1
# 라우터                       1
# CRM마케팅                    1
# 협회                        1
# 사단법인                      1
# NLU(자연어이해)                1
# VR(가상현실)                  1
# AR(증강현실)                  1
# PO(프로덕트오너)                1
# PMO                       1
# 편집디자인                     1
# 서류관리                      1
# 납품관리                      1
# 입찰                        1
# 목표관리                      1
# 예산관리                      1
# OpenCV                    1
# 게임개발자                     1
# 비즈니스마케팅                   1
# OracleDB                  1
# 통신                        1
# IPT                       1
# 웹 퍼블리셔                    1
# 웹 개발                      1
# 언리얼                       1
# 인터넷금융                     1
# 클라이언트                     1
# C++Builder                1
# 데이터 엔지니어                  1
# 서버 개발                     1
# 영업전략                      1
# 3D디자인                     1
# 의약사무                      1
# 기업홍보                      1
# 광고관리                      1
# 촬영                        1
# 그로스해킹                     1
# 거래처영업                     1
# 조직문화                      1
# SQA                       1
# 크리에이터                     1
# 뉴미디어                      1
# RPG                       1
# PL(프로젝트리더)                1
# NoSQL                     1
# PostgreSQL                1
# RestAPI                   1
# 검색엔진                      1
# AD(아트디렉터)                 1
# ReactJS                   1
# 인터넷생활정보                   1
# 포털                        1
# 물류센터                      1
# Eclipse                   1
# 급여(Payroll)               1
# IMC                       1
# 기업교육                      1
# 회원모집상담                    1
# 타이포그래피                    1
# Bootstrap                 1
# 가구디자인                     1
# 회계감사                      1
# 임베디드                      1
# 그래픽스                      1
# 소프트웨어 개발                  1
# 시스템공학                     1
# ITK                       1
# OpenGL                    1
# 아트워크                      1
# 회계법인                      1
# 3DMax                     1
# 3D                        1
# 3D온라인게임                   1
# Hadoop                    1
# TCG                       1
# MC                        1
# 아나운서                      1
# 쇼호스트                      1
# 사내방송                      1
# 리포터                       1
# CDMA                      1
# RFP(제안요청서)                1
# react/react native        1
# web/app 프론트               1
# 선적                        1
# 퍼포먼스마케팅                   1
# 캐릭터디자인                    1
# 정보설계                      1
# 건축설계                      1
# 가맹점영업                     1
# 도서·출판                     1
# 학습지·학원                    1
# 교육·출판                     1
# 학습지업체                     1
# 인터넷강의                     1
# 건축설비설계                    1
# 전기기사                      1
# 교재편집                      1
# 카탈로그편집                    1
# 출판                        1
# 온라인출판                     1
# 건축설비                      1
# 산업안전                      1
# MRO                       1
# 자재통합                      1
# 급여관리                      1
# 경영혁신                      1
# 안전관리                      1
# 서버엔지니어                    1
# 산업보건                      1
# 급여담당                      1
# uiux디자인                   1
# UIUX                      1
# 영상처리                      1
# 큐레이터                      1
# 폰트디자인                     1
# 포스터디자인                    1
# 전단지디자인                    1
# 인디자인                      1
# 북디자인                      1
# 전기공사                      1
# 전기배선                      1
# 사용자평가                     1
# 유통관리                      1
# 신기술영업                     1
# SCJP                      1
# ABAP                      1
# SAP                       1
# 베트남어                      1
# 패션브랜드                     1
# 직무분석                      1
# 전기설비                      1
# AE                        1
# 수출입계약                     1
# 구매관리                      1
# 재고관리                      1
# 식품MD                      1
# 국내영업                      1
# 언론홍보                      1
# 브랜드                       1
# 임원비서                      1
# UX기획                      1
# UI기획                      1
# UI/UX기획                   1
# 화면기획                      1
# 제품기획                      1
# HR컨설팅                     1
# 경영분석                      1
# 전문직업강사                    1
# 직업훈련교사                    1
# 부동산                       1
# 국가고시                      1
# 학원에이전트                    1
# 산업안전기사                    1
# 전기점검                      1
# 여행사                       1
# Name: 0, dtype: int64

# %%
print(len(intern))
# Out:
# 717

# %%
df3 = df3.drop_duplicates(keep='first').reset_index(drop=True)
df3

li = []
for idx in df3.index:
    print(df3.loc[idx, 0])
    li.append(df3.loc[idx, 0])
# Out:
# C++
# C언어
# Java
# 네트워크
# SQL
# S/W
# 브랜드디자인
# 데이터마이닝
# 데이터시각화
# 머신러닝
# 빅데이터
# AI(인공지능)
# 데이터분석가
# 사회조사
# 설문조사
# 백엔드/서버개발
# 솔루션
# RDBMS
# 시장조사
# 브랜드관리
# 브랜드기획
# SNS
# 브랜드마케팅
# 물류기사
# 배송기사
# 택배기사
# 1톤
# 화물차(카고)
# 네트워크보안
# 방화벽
# 보안컨설팅
# 정보보안
# 해킹
# QA
# 보안기술
# Linux
# Python
# 보안관리
# 유지보수
# 컴퓨터
# 하드웨어
# 데이터베이스
# 데이터분석
# 웹개발
# 웹마스터
# 앱개발
# 프론트엔드
# Android
# iOS
# 소프트웨어개발
# BI
# BigData
# SI
# 사무직
# 사무보조
# 자료입력
# SM
# 전산입력
# 전산편집
# 정보처리
# Excel
# 경영지원
# 정산관리
# 전산관련학과
# 전산학과
# 컴퓨터공학
# 프로그램 교육
# 프로그램 설치
# 문서관리
# 사무관리
# 사무행정
# 홈페이지관리
# 경리
# ERP운용
# 소프트웨어
# 교육진행
# 교육프로그램
# R&D
# 보안소프트웨어
# 기술지원
# 네트워크엔지니어
# 기술영업
# 콘텐츠기획
# 교수설계
# 대기환경
# 웹프로그래머
# HTML
# php
# C
# C#
# 펌웨어
# FPGA
# 기술연구
# 알고리즘개발
# 연구원
# 일본어
# SNS마케팅
# 일본어가능자
# 영업관리
# 영업지원
# 거래처관리
# 영업
# Javascript
# MySQL
# API
# 서무
# 총무
# 모바일개발
# 모바일플랫폼
# app개발
# 모바일UI개발
# 은행
# MS-SQL
# Oracle
# 아이폰
# 안드로이드
# 응용프로그래머
# R
# 모바일앱개발
# DataMining
# 마케팅
# PR
# SNS운영
# 해외마케팅
# jsp
# 인공지능(AI)
# 사물인터넷(IoT)
# 머신러닝(ML)
# AS
# 품질관리
# A·S
# 블록체인
# JSP
# 서비스기획
# 앱기획
# 솔루션영업
# 거래선개발관리
# 퍼블리셔
# CSS
# 기획MD
# 패션잡화
# 온라인마케팅
# 온라인MD
# AMD
# 온라인프로모션
# 온라인영업
# 프로게이머
# 교육상담
# 수강생관리
# 프로그램상담
# 학원운영
# 회원관리
# 스토리지
# 게임개발
# 게임디자인
# 게임운영관리
# 모바일앱게임
# 증강현실
# 딥러닝
# tensorflow
# 포워딩
# 항공운송
# 해상운송
# 수출입무역
# 사이트관리
# 온라인판매
# 쇼핑몰관리
# 리테일MD
# ICT컨설팅
# 컨설턴트
# 물류
# 문서작성
# 바이럴마케팅
# 웹마케팅
# 웹프로모션
# 게시판관리
# 쇼핑몰
# 웹사이트운영
# 카페·블로그관리
# 컨텐츠관리
# 웹접근성
# 웹표준
# 자바스크립트
# CSS3
# HTML코딩
# 드림위버
# 모바일UI
# 웹UI
# 일러스트레이터
# 포토샵
# GUI
# xml
# 영상편집
# 프리미어
# 모의해킹
# 알고리즘
# 취약점진단
# 클라우드
# Swift
# ERP
# .NET
# 웹기획
# PM(프로젝트매니저)
# UI/UX
# 채용담당자
# HRD
# HRM
# 채용공고관리
# 모바일게임
# 게임운영
# 캐주얼게임
# 게임CS
# MMORPG
# 입찰
# 납품관리
# 모바일
# 모바일기획
# 스토리보드
# 컨텐츠기획
# 비품관리
# 사내행사
# 서류관리
# 시설관리
# Flutter
# Kotlin
# 기획
# 모바일디자인
# 앱디자인
# 편집디자인
# UI/UX디자인
# 전략기획
# PMO
# PO(프로덕트오너)
# 리서치
# AR(증강현실)
# VR(가상현실)
# 공간디자인
# 그래픽디자인
# 통/번역
# 영어
# 중국어
# NLP(자연어처리)
# NLU(자연어이해)
# 사단법인
# 협회
# 콘텐츠마케팅
# CRM마케팅
# SE(시스템엔지니어)
# 라우터
# 브랜드런칭
# 브랜드확장
# 트렌드분석
# 상품기획
# 마케팅기획
# 마케팅전략
# 광고마케팅
# 글로벌마케팅
# 문구디자인
# 배너디자인
# 산업디자인
# 시각디자인
# 블로그마케팅
# 스포츠마케팅
# 인플루언서마케팅
# 학습매니저
# 교육컨텐츠기획
# 어학원
# 과외
# 고등학교
# IOS
# Node
# NODE.JS
# SWIFT
# Application
# 데이터분류
# DB 제작
# 모바일App
# 인사
# 섬유
# 의류
# 패션
# 전화응대
# 디지털디자인
# 제안서
# 사업기획
# 사업관리
# 웹퍼블리셔
# HTML5
# UI설계
# UI·UX
# UI·UX디자인
# 전자출판
# DevOps
# Azure
# Docker
# Kubernetes
# 면접/인터뷰
# 온보딩
# 인사행정
# 실내디자인
# 전시디자인
# 일러스트
# CAD
# IT컨설팅
# 인프라
# 솔루션기술영업
# 시스템영업
# 서버관리자
# 서버구축
# 시스템운영
# 시스템엔지니어
# 회계
# 재무
# 경영관리
# JavaScript
# kubernetes
# OpenStack
# React
# SPRING
# spring boot
# MLOps
# aiops
# 프론트 엔드
# 풀스택
# RESTful API
# Vue
# 오픈소스
# 자동화
# Ansible
# K8s
# 데이터 파이프라인
# dataops
# 소셜커머스
# 오픈마켓
# 전자상거래
# 인플루언서
# 경영기획
# 기획조사
# GM(게임운영)
# 교육운영
# ASP.NET
# WinForm
# AMQP
# RxJava
# RxSwift
# 스마트폰
# 병역특례
# 잡매니저
# 인사기획
# 광고디자인
# 웹디자인
# 미들웨어
# Apache
# PaaS
# Tomcat
# IaaS
# PhotoShop
# Ajax
# 핀테크
# 영업직
# 관공서
# 세종시
# PC유지보수
# PC
# 관공서 서버
# 관공서 유지보수
# 관공서 PC 유지보수
# 전산사무기기 유지보수
# ㈜아이넷
# 프린터 복사기
# 설치
# 수리
# PHP
# 영업기획
# 게임기획
# 게임마케팅
# 클라이언트개발
# 광고기획
# 광고대행
# 광고제작
# 온라인광고
# 홍보대행
# Windows
# 가상현실
# 디자이너
# 레벨
# 레벨 기획
# Unity
# 스팀게임
# 게임시나리오
# 콘솔게임
# 아키텍쳐
# AWS
# 2D디자인
# 게임소프트웨어
# 아트디렉터
# 영상디자인
# 크리에이티브디렉터
# 세재개발
# 브랜딩
# 소셜미디어
# 시장분석
# 업무제휴
# 퍼블리싱
# 프로모션
# 외자구매
# 자재관리
# 자재구매
# 자재구매기획
# 무역일반
# 바이어개발
# 바이어관리
# 바이어상담
# 해외영업
# MD
# 무역
# 무역사
# 무역사무
# 오더관리
# 상품입출고
# 슈퍼바이저
# 신상품개발
# 프랜차이즈
# VMD
# 고객상담
# 고객응대
# 고객지원
# 인바운드TM
# CS
# 제안·컨설팅
# 통계·로그분석
# PM
# 소셜마케팅
# 웹광고기획
# 컨텐츠개발
# 컨텐츠에디터
# CG
# 공업디자인
# 섬유디자인
# 잡화디자인
# 제품디자인
# 패키지디자인
# DM광고
# 자산관리
# 네트워크관리
# OA
# PowerPoint
# 스포츠강사
# 스포츠에이전트
# 생활체육
# 콘텐츠에디터
# 축구
# 백엔드개발
# 솔루션개발
# 프론트개발
# IT솔루션
# SW
# 건강
# 바이오
# 약국
# 영양
# 제약
# 검증
# 테스터
# GIS
# jquery
# 변화관리
# 사업제휴
# 전략
# 관리
# 문서수발
# 복리후생관리
# 교육
# 교육기획
# 노사관리
# 목표관리
# 성과관리
# 인사통합
# 인재개발
# 더존
# 전산회계
# 정보처리기사
# 결산
# 관리회계
# 부가세신고
# 예산관리
# 전표입력
# 광고관리
# 홍보
# 홍보기획
# 북디자인
# 인디자인
# 편집디자인(IBM)
# 전단지디자인
# 포스터디자인
# 폰트디자인
# 현수막디자인
# 큐레이터
# 영상처리
# 디지털마케팅
# 모바일마케팅
# 보안ASP
# 시스템설계
# 요구분석
# 작가
# PD/AD/FD
# 스토리텔링
# 그림작가
# 애니메이터
# UIUX
# uiux디자인
# 급여담당
# 산업보건
# 서버엔지니어
# 안전관리
# 경영혁신
# 신규사업·BD
# 출판기획
# 급여관리
# 자재통합
# MRO
# SCM
# 가맹점영업
# 일반영업
# 법인영업
# 도서·출판
# 학습지·학원
# 교육·출판
# 콜센터
# 학습지업체
# 웹서비스기획
# 키워드광고
# VB.NET
# 인터넷강의
# 건축설계
# 건축설비설계
# 교재편집
# 카탈로그편집
# 출판
# 온라인출판
# 건축설비
# 산업안전
# 전기공사
# 전기기사
# 전기배선
# 전기설비
# 전기점검
# 산업안전기사
# 학원에이전트
# 국가고시
# 부동산
# 직업훈련교사
# 전문직업강사
# 교육행정
# 교재컨텐츠개발
# 경영분석
# 경영컨설팅
# 웹컨설팅
# HR컨설팅
# 반응형웹
# 재무회계
# 제품기획
# 화면기획
# UI/UX기획
# UI기획
# UX기획
# 법무
# 채용·면접
# 비서
# 임원비서
# 브랜드
# 언론홍보
# 신기술영업
# Unix
# AJAX
# SCJP
# 전산전공
# ABAP
# SAP
# WAS
# 하둡(Hadoop)
# 자연어처리(NLP)
# 베트남어
# 패션브랜드
# 물류관리
# 유통관리
# 직무분석
# AE
# 수출입계약
# 구매관리
# 재고관리
# 식품MD
# 국내영업
# 매출관리
# 사용자평가
# 정보설계
# 캐릭터디자인
# 포토그래퍼
# 퍼포먼스마케팅
# 그로스해킹
# 디자인
# 거래처영업
# 고객관리
# 조직문화
# 데이터엔지니어
# QA/테스터
# SQA
# 크리에이터
# 뉴미디어
# 영상제작
# 촬영
# 웹에이전시
# GM·CS
# RPG
# 게임방송
# DBA
# NoSQL
# PostgreSQL
# MariaDB
# Node.js
# SI개발
# RestAPI
# 검색엔진
# AD(아트디렉터)
# 기자
# ReactJS
# Spring
# PL(프로젝트리더)
# 데이터라벨링
# 기업홍보
# 인터넷금융
# 콘텐츠관리
# 의약사무
# 비즈니스마케팅
# DBMS
# OracleDB
# 네트웍구축
# 통신
# IPT
# 무선통신
# 웹 퍼블리셔
# 웹 개발
# 프론트엔드 개발
# 가상화폐
# 개발자
# 게임개발자
# 백엔드
# 언리얼
# 코인
# 클라이언트
# C++Builder
# 데이터 엔지니어
# 서버 개발
# 애니메이션
# 영업전략
# 모델링
# 3D디자인
# 소셜네트워크서비스(SNS)
# 인터넷생활정보
# 커뮤니티
# 컨텐츠
# 포털
# 물류센터
# 세무
# 회계감사
# 선적
# 시스템프로그래머
# web/app 프론트
# react/react native
# RFP(제안요청서)
# CDMA
# 리포터
# 사내방송
# 쇼호스트
# 아나운서
# MC
# AR
# TCG
# 보드게임
# 캐릭터
# asp
# Hadoop
# Spark
# 3D온라인게임
# 3D
# 3DMax
# 회계법인
# 콘텐츠디자인
# 아트워크
# 급여(Payroll)
# CRM
# IMC
# 기업교육
# 회원모집상담
# 타이포그래피
# Figma
# Bootstrap
# Eclipse
# Git
# jQuery
# 가구디자인
# ISP
# VisualC++
# 임베디드
# 그래픽스
# 소프트웨어 개발
# 시스템공학
# ITK
# OpenGL
# OpenCV
# VTK
# webgl
# 3D모델편집
# 챗봇(Chatbot)
# 원화디자인
# 관리자
# 세일즈
# 영업보조
# 인사담당
# 전산
# 한국어
# POS
# 프로토타이핑
# 소비재
# 4대보험
# 이카운트
# 보안관제
# 웹게임
# Java게임
# 트러블슈팅
# 기업영업
# 납기관리
# MVP패턴
# REST
# 유닛테스트
# DW
# Cisco
# IT학원
# 타당성분석
# 상품분석
# 회원분석
# UI디자인
# UX디자인
# 건설
# 측량
# 토목
# 도시계획
# 시스템분석
# 유비쿼터스
# MFC
# 마켓팅
# 어린이집
# 유아원
# 유아원교사
# 유치원교사
# 플래쉬
# 인터넷방송
# 프로덕션
# DataWarehouse
# ESM
# 스튜디오
# 콜센터운영
# 디자인기타
# 이커머스 개발
# 교육훈련
# e스포츠
# 문화기획
# 서버
# APM
# Servlet
# VisualBasic
# 인공지능 서비스 기획자
# 전자
# 공정
# 공정관리
# 생산
# 생산관리
# GIT
# express
# SPA
# 자동차
# 정보통신
# 캐셔
# 판매직
# 유통·상품기획·MD
# 소프트웨어·하드웨어
# 통신·모바일
# 전산·IT기술지원
# 기계·금속·재료
# 기계·금속기능
# 섬유·화학
# 웹기획·웹마케팅·PM
# 빅데이터·AI(인공지능)
# 조사·분석·통계
# IT·문화·직업강사
# 출판·편집디자인
# 매장관리
# ERP·시스템분석·설계
# 게임(Game)
# 광고·CG·시각디자인
# 캐릭터·애니메이션
# 재무·자금·IR
# 세무·회계
# 경영·기획·전략
# 데이터베이스·DBA
# 구매·자재
# 운송·물류
# 영업관리·영업지원
# 인사·채용·인재개발(HRM·HRD)
# 비서·안내
# 일반사무·사무지원
# 건축·공간·CAD·CAM디자인
# 건설현장
# 네트워크·서버·보안
# 운전·운항
# 일반·법인영업
# 방송제작·연출·촬영·기자
# 금융사무·심사·추심
# 컨텐츠·사이트운영
# 생산·조립·가공·포장·검품
# 식품가공·농림어업
# 임원·경영분석·컨설팅
# 멀티미디어(동영상·음향)
# 전기·소방·설비
# 연구원·연구개발
# 총무·법무·특허
# 제품·산업디자인
# 광고·광고기획(AE)
# 홍보·PR·전시·컨벤션
# 광고영업
# 패션·잡화디자인
# 전문번역·통역
# 인문사회연구·종교
# 법률·법무·회계
# 건축·인테리어·설계
# 토목·조경·도시·측량
# 전자·반도체
# 진행·연예·모델·매니저
# 간호·간병
# 여행·레저
# HTML·퍼블리싱·UI개발
# 이벤트·나레이터·결혼
# 설치·수리·정비·A/S
# 광학·의료장비
# 전기·전자·통신기능
# Embedded
# IT영업
# H/W
# 세무기장
# 세무신고
# 세무회계
# 회계결산
# 로고디자인
# 데이터라벨러
# KMS
# Sybase
# 전자정부프레임워크
# PL
# springboot
# SpringFramework
# 방송기획
# 방송제작
# PD·연출
# 교육·교재개발
# 연구소
# OCP
# 이벤트프로모션
# 스마트폰게임
# 카페운영
# GM
# CX매니저
# 인바운드
# 인터넷게임
# 인터넷교육
# ReactNative
# 웹표준·웹접근성
# 이미지프로세싱
# 인터페이스
# angularjs
# 골프장
# 스포츠
# HDML
# OLAP
# ATL
# BTL
# 무인항공기/드론
# 사업개발
# 신사업기획
# 웹프로덕션
# 학원강사
# 컴퓨터학원강사
# IT학원강사
# 의약품
# 법인결산
# 자금관리
# 리액트
# Front-end
# react.js
# B2C
# Back-end
# Sketch
# Zeplin
# 제조
# 조립
# 리액트 네이티브
# Django
# Flask
# 생명공학
# 의약
# 자동제어
# 전기
# 전기제어
# 제어
# VisualC
# 컨설팅
# 백엔드 개발
# 임베디드 개발
# 모바일 앱 개발 iOS/Android
# Nodejs
# 리눅스
# 원화
# DB2
# PowerBuilder
# 자동차보험
# 건강보험
# 대물보상
# 대인보상
# 리스크관리
# 손익관리
# 일반보험
# Agile
# Akka
# Architect
# FRM
# FrameWork
# IFRS17
# ISMS
# JVM
# SCRUM
# 대인보상기획
# 인프라AA
# 손해보험
# 손해사정
# 송무
# 인허가업무
# 개인고객영업
# 법인고객영업
# 보험설계
# 보험영업
# 보험
# 아웃바운드TM
# 보험회사
# 제품홍보
# 튜닝
# 보험심사·청구
# 보상
# 보험심사
# 보험계리사
# 언더라이팅
# 의료기기
# 앱 개발자
# Xamarin
# 프리뷰어
# CW(카피라이터)
# VMware
# BI디자인
# IR/공시
# CFO
# 고객상담·관리·수퍼바이저
# ASP
# 투자·분석·증권·외환
# 전산총무
# AE(광고기획자)
# 광고PD
# 검색광고
# 작가·문화·예술·창작
# 악성코드
# SEO
# SAS
# 애널리스트
# 유튜브
# 애프터이펙트
# 안내데스크
# 내방객응대
# Nginx
# 자료조사
# A/S기사
# 기계수리
# 영업마케팅
# XD
# 관광가이드
# 관광통역안내사
# 여행사

# %%
cnt_ai = 0
cnt_data = 0
cnt_web = 0
cnt_app = 0
cnt_network = 0
cnt_system = 0
df = pd.DataFrame(intern)

for i in range(len(df)):
    tmp = df.iloc[i][0]
    if 'iOS' in tmp or '앱' in tmp or '게임' in tmp or '소프트웨어' in tmp or '응용' in tmp:
        cnt_app += 1
    if 'AI' in tmp or 'IoT' in tmp or '러닝' in tmp or '인공지능' in tmp: 
        cnt_ai += 1
    if '웹' in tmp or '엔드' in tmp or 'HTML' in tmp or 'web' in tmp or 'CSS' in tmp:
        cnt_web += 1
    if '데이터' in tmp or 'DB' in tmp or 'SQL' in tmp:
        cnt_data += 1
    if '서버' in tmp or '블록체인' in tmp or '보안' in tmp or 'Node.js' in tmp:
        cnt_network += 1
    if 'Unix' in tmp or 'Linux' in tmp or '임베디드' in tmp or '시스템' in tmp:
        cnt_system += 1
    
print(cnt_network,' ', cnt_system, ' ', cnt_ai, ' ', cnt_data, ' ', cnt_web, ' ', cnt_app)
# Out:
# 37   15   38   78   96   64

# %%
tmp_tags = pd.DataFrame({'응용 소프트웨어 개발자' :[], '웹 개발자':[], '데이터 전문가':[], '네트워크/ 서버/ 보안':[], '시스템 소프트웨어':[], '인공지능(AI)':[]})

app = []
web = []
data = []
network = []
system = []
Ai = []
other = []
garbage = []

for i in li:
    if '웹' in i or '엔드' in i or 'HTML' in i:
        web.append(i)
        continue
    if '데이터' in i or 'DB' in i:
        data.append(i)
        continue
    if '블록체인' in i or '보안' in i :
        network.append(i)
        continue
    if 'Unix' in i or 'Linux' in i or '임베디드' in i:
        system.append(i)
        continue
    if '러닝' in i or 'AI' in i:
        Ai.append(i)
        continue
    if '영업' in i or '마케팅' in i or '조사' in i or '기사' in i or '기획' in i:
        garbage.append(i)
        continue
    else:
        other.append(i)

#df = pd.DataFrame(zip(app, web, data, network, system), columns=['응용', '웹', '데이터', '네트워크', '시스템'])
df = pd.DataFrame({'웹':pd.Series(web), '데이터':pd.Series(data), '네트워크/ 서버/ 보안':pd.Series(network) , '시스템':pd.Series(system), '인공지능':pd.Series(Ai)}) #'그 외':pd.Series(other)
df
# Out:
#                  웹            데이터 네트워크/ 서버/ 보안      시스템      인공지능
# 0         백엔드/서버개발         데이터마이닝       네트워크보안    Linux      머신러닝
# 1              웹개발         데이터시각화        보안컨설팅     Unix  AI(인공지능)
# 2             웹마스터           빅데이터         정보보안     임베디드  인공지능(AI)
# 3            프론트엔드         데이터분석가         보안기술  임베디드 개발  머신러닝(ML)
# 4           웹프로그래머          RDBMS         보안관리      NaN       딥러닝
# 5             HTML         데이터베이스      보안소프트웨어      NaN       NaN
# 6             웹마케팅          데이터분석         블록체인      NaN       NaN
# 7            웹프로모션          데이터분류        보안ASP      NaN       NaN
# 8           웹사이트운영          DB 제작         보안관제      NaN       NaN
# 9             웹접근성      데이터 파이프라인   네트워크·서버·보안      NaN       NaN
# 10             웹표준        데이터엔지니어          NaN      NaN       NaN
# 11          HTML코딩            DBA          NaN      NaN       NaN
# 12             웹UI        MariaDB          NaN      NaN       NaN
# 13             웹기획         데이터라벨링          NaN      NaN       NaN
# 14           웹퍼블리셔           DBMS          NaN      NaN       NaN
# 15           HTML5       OracleDB          NaN      NaN       NaN
# 16          프론트 엔드       데이터 엔지니어          NaN      NaN       NaN
# 17            웹디자인  빅데이터·AI(인공지능)          NaN      NaN       NaN
# 18           웹광고기획     데이터베이스·DBA          NaN      NaN       NaN
# 19           백엔드개발         데이터라벨러          NaN      NaN       NaN
# 20          웹서비스기획            DB2          NaN      NaN       NaN
# 21            웹컨설팅            NaN          NaN      NaN       NaN
# 22            반응형웹            NaN          NaN      NaN       NaN
# 23           웹에이전시            NaN          NaN      NaN       NaN
# 24          웹 퍼블리셔            NaN          NaN      NaN       NaN
# 25            웹 개발            NaN          NaN      NaN       NaN
# 26        프론트엔드 개발            NaN          NaN      NaN       NaN
# 27             백엔드            NaN          NaN      NaN       NaN
# 28             웹게임            NaN          NaN      NaN       NaN
# 29     웹기획·웹마케팅·PM            NaN          NaN      NaN       NaN
# 30  HTML·퍼블리싱·UI개발            NaN          NaN      NaN       NaN
# 31        웹표준·웹접근성            NaN          NaN      NaN       NaN
# 32           웹프로덕션            NaN          NaN      NaN       NaN
# 33          백엔드 개발            NaN          NaN      NaN       NaN
