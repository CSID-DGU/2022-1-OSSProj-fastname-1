# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
from bs4 import BeautifulSoup
import re
import urllib.request
from urllib.request import urlopen
import ssl
from dateutil.parser import parse
import json
import requests
context=ssl._create_unverified_context()

# %%
web_title=[]
web_host=[]
web_dday=[]
web_qualification=[]
web_links=[]

base_url='https://www.saramin.co.kr/zf_user/search/recruit?searchType=search&searchword=%EC%9D%B8%ED%84%B4%EC%8B%AD&cat_kewd=87&panel_type=&search_optional_item=y&search_done=y&panel_count=y&abType=a&show_applied=&except_read=&ai_head_hunting=&mainSearch=n&recruitPage=1&recruitSort=relation&recruitPageCount=40&inner_com_type=&company_cd=0%2C1%2C2%2C3%2C4%2C5%2C6%2C7%2C9%2C10&quick_apply='
webpage = urlopen(base_url,context=context)
soup = BeautifulSoup(webpage, 'html.parser')
pagenum = len(soup.select('div.content_bottom > div > a'))
#recruit_info_list > div.content > div:nth-child(1) > div.area_job > h2 > a > span
title = soup.select('div.item_recruit')
print(title)

'''
for i in range(1, pagenum+1):
    url = 'https://www.saramin.co.kr/zf_user/search/recruit?searchType=search&searchword=%EC%9D%B8%ED%84%B4%EC%8B%AD&cat_kewd=87&company_cd=0%2C1%2C2%2C3%2C4%2C5%2C6%2C7%2C9%2C10&panel_type=&search_optional_item=y&search_done=y&panel_count=y&abType=a&recruitPage='+str(i)+'&recruitSort=relation&recruitPageCount=40&inner_com_type=&show_applied=&quick_apply=&except_read=&ai_head_hunting=&mainSearch=n'
    webpage = urlopen(url,context=context)
    soup = BeautifulSoup(webpage, 'html.parser')
    title = soup.select('#recruit_info_list > div.content > div.item_recruit.visited.has_similar_list > div.area_job > h2 > a > span')
'''
# Out:
# [<div class="item_recruit" data-data_layer="keyword_free|paid_n_quick" value="43102270">
# <div class="area_job">
# <h2 class="job_tit">
# <a class="data_layer" data-data_layer="keyword_free|paid_n" href="/zf_user/jobs/relay/view?view_type=search&amp;rec_idx=43102270&amp;location=ts&amp;searchword=%EC%9D%B8%ED%84%B4%EC%8B%AD&amp;searchType=search&amp;paid_fl=n&amp;search_uuid=4d2d2357-52ee-4af9-b69e-d544d7215813" onclick="try{s_trackApply(this, 'search', 'generic')}catch(e){};" rel="" target="_blank" title="제2기 서울 우먼업(WomanUp) 인턴십 참여자(인턴) 모집 공고"><span>제2기 서울 우먼업(WomanUp) <b>인턴십</b> 참여자(인턴) 모집 공고</span></a> </h2>
# <div class="toolTipWrap wrap_scrap">
# ...
